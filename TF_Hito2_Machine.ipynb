# %% [markdown]
# #***Alumnos***

# %% [markdown]
# - ***Geral Esteen Castillo Arredondo U201716913***
#
# - ***Javier Arturo Rozas Acurio U201711814***

# %% [markdown]
# #***Enlace Online***

# %% [markdown]
# **[Link de Acceso](https://colab.research.google.com/drive/1tgs1WIBIGpF3Sns0hODNyi-LOnULPfRp?usp=sharing)**

# %% [markdown]
# #***Indice***

# %% [markdown]
# I. ***Lectura y Descripción de los datos***
#
# 1. ***Lectura de datos***
#
# 2. ***Descripción del conjunto de datos***
#
# II. ***Preprocesamiento de datos***
#
# 1. ***Reducción de datos***
#
# 2. ***Limpieza y tratamiento de datos***
#
#    A. ***Eliminación de datos duplicados***
#
#    B. ***Tratamiento de Outliers***
#
#    C. ***Detección de inconsistencia de datos***
#
#    D. ***Tratamiento de valores faltantes***
#
#    E. ***Transformación de datos categoricos***
#
# 3. ***Aplicación de Under-sampling***
#
# 4. ***Transformación de datos***
#
#    A. ***Evaluación para normalización o estandarización de datos***
#
#     * A.1. ***Aplicación de normalización***
#
#     * A.2. ***Aplicación de estandarización***
#
#     * A.3. ***Comparación y conclusión sobre la mejor técnica***
#
# 5. ***Feature Selection***
#
#    A. ***Aplicación de Análisis de componentes principales (PCA)***
#
#    B. ***Aplicación de Método de filtrado con correlación de Pearson***
#
#    C. ***Aplicación de Método Wrapper: Eliminación hacia atrás***
#
#    D. ***Aplicación de Método Wrapper: Eliminación de Característica Recursiva***
#
#    E. ***Aplicación de Método embebido***
#
#    F. ***Aplicación de Árboles extremadamente aleatorizados (Extra Tree Classifier) para selección de caracteristicas***
#
#    G. ***Aplicación de Selección Univariante***
#
#    H. ***Comparación y Conclusión sobre la mejor técnica***
#
# III. ***Prueba con Clasificadores***
#
# 1. ***Análisis de hiperparámetros con métricas de desempeño***
#
#   A. ***K Vecinos más Cercanos (KNN)***
#
#     * A.1. ***Mejores hiperparametros según metrica de Exactitud (Accuracy)***
#
#     * A.2. ***Mejores hiperparametros según metrica de Precisión (precision)***
#
#     * A.3. ***Mejores hiperparametros según metrica de Recall***
#
#     * A.4. ***Mejores hiperparametros según metrica de F1***
#
#     * A.5. ***Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***
#
#     * A.6. ***Comparación y Síntesis***
#
#   B. ***Arbol de Decisión***
#
#     * B.1. ***Mejores hiperparametros según metrica de Exactitud (Accuracy)***
#
#     * B.2. ***Mejores hiperparametros según metrica de Precisión (precision)***
#
#     * B.3. ***Mejores hiperparametros según metrica de Recall***
#
#     * B.4. ***Mejores hiperparametros según metrica de F1***
#
#     * B.5. ***Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***
#
#     * B.6. ***Comparación y Síntesis***
#
#   C. ***Máquinas de Vectores de Soporte (SVM)***
#
#     * C.1. ***Mejores hiperparametros según metrica de Exactitud (Accuracy)***
#
#     * C.2. ***Mejores hiperparametros según metrica de Precisión (precision)***
#
#     * C.3. ***Mejores hiperparametros según metrica de Recall***
#
#     * C.4. ***Mejores hiperparametros según metrica de F1***
#
#     * C.5. ***Comparación y Síntesis***
#
#    D. ***Random Forest***
#
#    * D.1. ***Mejores hiperparametros según metrica de Exactitud (Accuracy)***
#
#    * D.2. ***Mejores hiperparametros según metrica de Precisión (precision)***
#
#    * D.3. ***Mejores hiperparametros según metrica de Recall***
#
#    * D.4. ***Mejores hiperparametros según metrica de F1***
#
#    * D.5. ***Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***
#
#    * D.6. ***Comparación y Síntesis***
#
#    E. ***Regresión Logistica (Logistic Regression)***
#
#    * E.1. ***Mejores hiperparametros según metrica de Exactitud (Accuracy)***
#
#    * E.2. ***Mejores hiperparametros según metrica de Precisión (precision)***
#
#    * E.3. ***Mejores hiperparametros según metrica de Recall***
#
#    * E.4. ***Mejores hiperparametros según metrica de F1***
#
#    * E.5. ***Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***
#
#    * E.6. ***Comparación y Síntesis***
#
#    F. ***Redes Bayesianas Multinomiales (Multinomial Naive Bayes)***
#
#    * F.1. ***Mejores hiperparametros según metrica de Exactitud (Accuracy)***
#
#    * F.2. ***Mejores hiperparametros según metrica de Precisión (precision)***
#
#    * F.3. ***Mejores hiperparametros según metrica de Recall***
#
#    * F.4. ***Mejores hiperparametros según metrica de F1***
#
#    * F.5. ***Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***
#
#    * F.6. ***Comparación y Síntesis***
#
# 2. ***Análisis del mejor clasificador con métricas de desempeño***
#
#    A. ***Análisis del mejor modelo de K Vecinos más Cercanos (KNN)***
#
#    * A.1. ***Evaluación según metrica de Exactitud (Accuracy)***
#
#    * A.2. ***Evaluación según metrica de Precisión (Precision)***
#
#    * A.3. ***Evaluación según metrica de Recall***
#
#    * A.4. ***Evaluación según metrica de F1***
#
#    * A.5. ***Evaluación según metrica de Área bajo la Curva ROC (AUC)***
#
#    * A.6. ***Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***
#
#    B. ***Análisis del mejor modelo de Árbol de Decisión***
#
#    * B.1. ***Evaluación según metrica de Exactitud (Accuracy)***
#
#    * B.2. ***Evaluación según metrica de Precisión (Precision)***
#
#    * B.3. ***Evaluación según metrica de Recall***
#
#    * B.4. ***Evaluación según metrica de F1***
#
#    * B.5. ***Evaluación según metrica de Área bajo la Curva ROC (AUC)***
#
#    * B.6. ***Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***
#
#    C. ***Análisis del mejor modelo de Máquinas de Vectores de Soporte (SVM)***
#
#    * C.1. ***Evaluación según metrica de Exactitud (Accuracy)***
#
#    * C.2. ***Evaluación según metrica de Precisión (Precision)***
#
#    * C.3. ***Evaluación según metrica de Recall***
#
#    * C.4. ***Evaluación según metrica de F1***
#
#    * C.5. ***Evaluación según metrica de Área bajo la Curva ROC (AUC)***
#
#    * C.6. ***Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***
#
#    D. ***Análisis del mejor modelo de Random Forest***
#
#    * D.1. ***Evaluación según metrica de Exactitud (Accuracy)***
#
#    * D.2. ***Evaluación según metrica de Precisión (Precision)***
#
#    * D.3. ***Evaluación según metrica de Recall***
#
#    * D.4. ***Evaluación según metrica de F1***
#
#    * D.5. ***Evaluación según metrica de Área bajo la Curva ROC (AUC)***
#
#    * D.6. ***Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***
#
#    E. ***Análisis del mejor modelo de Regresión Logistica (Logistic Regression)***
#
#    * E.1. ***Evaluación según metrica de Exactitud (Accuracy)***
#
#    * E.2. ***Evaluación según metrica de Precisión (Precision)***
#
#    * E.3. ***Evaluación según metrica de Recall***
#
#    * E.4. ***Evaluación según metrica de F1***
#
#    * E.5. ***Evaluación según metrica de Área bajo la Curva ROC (AUC)***
#
#    * E.6. ***Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***
#
#    F. ***Análisis del mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes)***
#
#    * F.1. ***Evaluación según metrica de Exactitud (Accuracy)***
#
#    * F.2. ***Evaluación según metrica de Precisión (Precision)***
#
#    * F.3. ***Evaluación según metrica de Recall***
#
#    * F.4. ***Evaluación según metrica de F1***
#
#    * F.5. ***Evaluación según metrica de Área bajo la Curva ROC (AUC)***
#
#    * F.6. ***Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***
#
#    G. ***Comparación y Conclusiones***
#
#    * G.1. ***Gráfico de Curvas Receiver Operating Characteristics (ROC) para K Vecinos más Cercanos (KNN)***
#
#    * G.2. ***Gráfico de Curvas Receiver Operating Characteristics (ROC) para Maquinas de Vectores de Soporte (SVM)***
#
#    * G.3. ***Gráfico de Curvas Receiver Operating Characteristics (ROC) para Random Forest***
#
#    F. ***Identificación de Overfitting en los mejores modelos encontrados***
#
#    * F.1. ***Identificación de Overfitting para K Vecinos más Cercanos (KNN)***
#
#    * F.2. ***Identificación de Overfitting para Maquinas de Vectores de Soporte (SVM)***
#
#    * F.3. ***Identificación de Overfitting para Random Forest***
#
# 3. ***Aplicación de aprendizaje no supervisado***
#
#    A. ***Aplicación de K-means***
#
#    * A.1. ***Visualización de K-means: Comerciante (merchant) vs Categoría (category)***
#
#    * A.2. ***Visualización de K-means: Comerciante (merchant) vs Cantidad (amount)***
#
#    * A.3. ***Visualización de K-means: Categoría (category) vs Cantidad (amount)***
#
#    * A.4. ***Visualización de K-means: Comerciante (merchant) vs Categoría (category) vs Cantidad (amount)***
#
#    * A.5. ***Identificación de patrones y Conclusiones***

# %% [markdown]
# #***I. Lectura y Descripción de los datos***

# %% [markdown]
# ##***1. Lectura de datos***

# %% [markdown]
# En las siguientes celdas de codigo, se lee el conjunto de datos respectivo desde google drive. El archivo correspondiente a leer posee como nombre ***fraude.csv***.

# %%
#Leer un CSV 
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials 
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import pandas as pd
import numpy as np
from google.colab import data_table

link_google_drive = 'https://drive.google.com/open?id=1Dj-qJ6qh5XQRbxtwXrfU-kVME9RItFyp'
flu, id = link_google_drive.split('=')
dataset = drive.CreateFile({'id':id})
dataset.GetContentFile('fraude.csv')
df = pd.read_csv('fraude.csv')
df.head()
# Out:
#    step       customer  age  ...             category amount fraud
# 0     0  'C1093826151'  '4'  ...  'es_transportation'   4.55     0
# 1     0   'C352968107'  '2'  ...  'es_transportation'  39.68     0
# 2     0  'C2054744914'  '4'  ...  'es_transportation'  26.89     0
# 3     0  'C1760612790'  '3'  ...  'es_transportation'  17.25     0
# 4     0   'C757503768'  '5'  ...  'es_transportation'  35.72     0
#
# [5 rows x 10 columns]

# %% [markdown]
# ##***2. Descripción del conjunto de datos***

# %% [markdown]
# ***Contexto del dataset:*** BankSim es un simulador basado en agentes de pagos bancarios basado en una muestra de datos transaccionales agregados proporcionados por un banco en España. El objetivo principal de BankSim es la generación de datos sintéticos que pueden utilizarse para la investigación de detección de ***fraude***. El análisis estadístico y un análisis de redes sociales (SNA) de las relaciones entre comerciantes y clientes se utilizaron para desarrollar y calibrar el modelo. Nuestro objetivo final es que BankSim pueda utilizarse para modelar escenarios relevantes que combinen pagos normales e inyectan firmas de ***fraude*** conocidas.
#
# Ahora bien, se procedera a definir cada atributo del conjunto de datos obtenido y a identificar el atributo clase o objetivo:
#
# ***Caracteristicas***
#
# * **Paso (step):** indica el ***step*** relacionado a la transacción.
#
# * **Cliente (customer):** indica el codigo del cliente.
#
# * **Edad (age):** indica la edad del cliente.
#
# * **Genero (gender):** indica el genero, masculino o femenino, del cliente.
#
# * **Origen de codigo postal (zipcodeOri):** indica el origen de codigo postal del cliente.
#
# * **Comerciante (merchant):** indica el codigo del comerciante.
#
# * **Postal del Comerciante (zipMerchant):** indica el codigo postal del comerciante.
#
# * **Categoria (category):** indica la categoria del pago bancario.
#
# * **Cantidad (amount):** indica la cantidad pagada.
#
# ***Atributo clase o objetivo***
#
# * ***Fraude (fraud):*** indica si la transacción se trata de un ***fraude*** o no. Siendo ***1*** si se trata de un ***fraude*** y ***0*** en caso contrario. Cabe mencionar que la ***clase positiva*** es ***fraude (1)*** y la ***clase negativa*** es ***no fraude (0)***.

# %% [markdown]
# #***II. Preprocesamiento de datos***

# %% [markdown]
# ##***1. Reducción de datos***

# %% [markdown]
# Se deben eliminar aquellos datos irrelevantes, que no sean utiles para el proceso de clasificación. En este caso, para identificarlos, se hizo uso de la herramienta Orange. A continuación, se muestra una tabla con datos estadisticos de algunas columnas del conjunto de datos. Se puede observar que las caracteristicas ***zipcodeOri*** y ***zipMerchant*** presentan una dispersión de ***0.00*** con un valor maximo y minimo igual a ***28007.00***.
#
# ![Datos estadisticos de caracteristicas](https://i.ibb.co/wcb7Lvk/zip-ban.png)
#
# Asimismo, de acuerdo a la información presentada en ***Kagle***, plataforma de la cual se obtuvo el conjunto de datos, se puede observar lo siguiente:
#
# * ***ZipcodeOri***
#
# ![zipcodeOri es unico](https://i.ibb.co/wcsZv4L/zipcodeban.png)
#
# * ***ZipMerchant***
#
# ![ZipMerchant es unico](https://i.ibb.co/kKMVMmc/zipmerchban.png)
#
# Es posible observar que las columnas ***zipcodeOri*** y ***zipMerchant*** presentan un unico y mismo valor para todos los registros. Por lo tanto, el valor de dichas columnas no aporta en el proceso de determinación de fraude. En ese sentido, es apropiado eliminar aquellas caracteriticas, reduciento así la dimensionalidad de los datos.
#
# ***Conclusión: Las columnas zipcodeOri y zipMerchant son irrelevantes, y deben ser eliminadas***

# %% [markdown]
# El siguiente codigo logra eliminar las columnas especificadas. En primer lugar, se obtienen y guardan los nombres de cada columna en un arreglo. Luego de la eliminación de las columnas respectivas, se imprime los primeros 5 registros del conjunto de datos, para evidenciar el cambio. ***Esta parte, no es del todo generica***. Esto sucede, ya que se deben indicar los indices de las columnas a eliminar.

# %%
#Guardando el nombre de las columnas del dataset en un arreglo
names = df.columns.values

# %%
ind_col1 = 4 #Se debe indicar indice de la primer columna
ind_col2 = 6 #Se debe indicar indice de la segunda columna
df = df.drop([names[ind_col1], names[ind_col2]], axis=1)
df.head()
# Out:
#    step       customer  age  ...             category amount fraud
# 0     0  'C1093826151'  '4'  ...  'es_transportation'   4.55     0
# 1     0   'C352968107'  '2'  ...  'es_transportation'  39.68     0
# 2     0  'C2054744914'  '4'  ...  'es_transportation'  26.89     0
# 3     0  'C1760612790'  '3'  ...  'es_transportation'  17.25     0
# 4     0   'C757503768'  '5'  ...  'es_transportation'  35.72     0
#
# [5 rows x 8 columns]

# %% [markdown]
# ##***2. Limpieza y tratamiento de datos***

# %% [markdown]
# ###***A. Eliminación de datos duplicados***

# %% [markdown]
# Se deben eliminar los datos redundantes que se puedan encontrar en la data, ya que tener datos duplicados no representa ninguna ganacia de información. El siguiente codigo sirve para eliminar los datos duplicados.

# %%
#Eliminar registros duplicados en la data
df = df.drop_duplicates()

# %% [markdown]
# Ahora bien, se comprobara que no haya registros duplicados con el siguiente codigo, el cual imprime la cantidad de registros duplicados en el conjunto de datos.

# %%
#identificar si hay valores duplicados
ddf = df.duplicated()
n_vdupli = 0 #numeros de valores duplicados
for i in range(len(ddf)):
  if (ddf[i] == True):
    n_vdupli += 1
print(n_vdupli)
# Out:
# 0

# %% [markdown]
# ###***B. Tratamiento de Outliers***

# %% [markdown]
# Ahora bien, se procedera a identificar la posible precencia de outliers en cada atributo numerico del conjunto de datos.
#
# * ***Paso (Step)***
#
# ![Boxplot Step](https://i.ibb.co/86ydtpK/boxstep.png)
#
# **Se debe considerar el Rango: [0; 179]**
#
# * ***Cantidad (Amount)***
#
# ![Boxplot Amount](https://i.ibb.co/LC1Z5g0/boxamount.png)
#
# **Se debe considerar el Rango: [0; 8329.96]**
#
# * ***Fraude (Fraud)***
#
# ![Boxplot Fraud](https://i.ibb.co/TR2GkW2/boxfraud.png)
#
# **Se debe considerar el Rango: [0; 1]**
#
# ***Conclusión: Como se puede apreciar en los diagramas de caja dados anteriormente, no existen valores que superen los extremos superiores e inferiores en ninguno de ellos. Por lo tanto, se concluye que no existen outliers o valores atipicos con respecto a atributos numericos en el conjunto de datos analizado.***

# %% [markdown]
# ###***C. Detección de inconsistencia de datos***

# %% [markdown]
# Se utilizo la herramienta ***Orange*** para la determinación de valores inconsistentes o inconsistencia en los datos. A continuación, se muestran las estadisticas de los datos dados por la herramienta mencionada:
#
# ![Estadistica de atributos](https://i.ibb.co/h1JvCmp/sta-fra.png)
#
# De acuerdo a la información dada anteriormente, no se a logrado identificar ningun tipo de inconsistencia en ningun atributo con respecto a el rango, la media, dispersión y otros valores estadisticos analizados.
#
# ***Conclusión: No hay una inconsistencia significativa en los datos***

# %% [markdown]
# ###***D. Tratamiento de valores faltantes***

# %% [markdown]
# A continuación, se imprimen los valores faltantes por cada columna. En este caso, podemos identificar que no hay valores faltantes en el conjunto de datos.
#
# ***Conclusión: no se logro identificar valores nulos en los datos dados.***

# %%
 print("cantidad de registros: ", len(df))
 df.isnull().sum()
# Out:
# cantidad de registros:  594643
# step        0
# customer    0
# age         0
# gender      0
# merchant    0
# category    0
# amount      0
# fraud       0
# dtype: int64

# %% [markdown]
# ###***E. Transformación de datos categoricos***

# %% [markdown]
# La mayoria de modelos de aprendizaje solo entienden de datos numericos. En ese sentido, es apropiado codificar las variables categoricas del conjunto de datos. A continuación, se realiza lo especificado. Se imprimen las primeras 5 instancias del conjunto de datos con las variables categoricas codificadas a numeros.

# %%
from sklearn.preprocessing import LabelEncoder
#Codificando todas las variables categoricas, ya que los clasificadores solo entienden datos numericos
categorical_feature_mask = df.dtypes==object
categorical_cols = df.columns[categorical_feature_mask].tolist()
le = LabelEncoder()
df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))
df.head()
# Out:
#    step  customer  age  gender  merchant  category  amount  fraud
# 0     0       210    4       2        30        12    4.55      0
# 1     0      2753    2       2        30        12   39.68      0
# 2     0      2285    4       1        18        12   26.89      0
# 3     0      1650    3       2        30        12   17.25      0
# 4     0      3585    5       2        30        12   35.72      0

# %% [markdown]
# ##***3. Aplicación de Under-sampling***

# %% [markdown]
# Se ha logrado detectar que existe un desbalance de datos muy significativo en el conjunto de datos. Un conjunto de datos está desequilibrado o desbalanceado si al menos una de las clases constituye solo una minoría muy pequeña. En este caso, la diferencia de cantidad entre clases es enorme. A continuación, se imprime la cantidad de instancias por cada clase de la columna objetivo ***Fraude (fraud)***. En ese sentido, existen ***587,443*** instancias de ***No fraude (0)*** y ***7,200*** instancias de ***Fraude (1)***, comprobandose lo argumentado.

# %%
ind_clase = 7
names = df.columns.values
df[names[ind_clase]].value_counts()
# Out:
# 0    587443
# 1      7200
# Name: fraud, dtype: int64

# %% [markdown]
# Como solución a este problema, se propone aplicar una tecnica de ***Under-sampling***. Ahora bien, se debe explicar en que consisten este tipo de tecnicas. ***Under-sampling*** se basa en reducir la cantidad de instancias de la clase mayoritaria, en este caso la clase ***No fraude (0)***, de tal manera que todas las clases de la columna objetivo tengan la misma cantidad de instancias. Al reducir la cantidad de instacncias, se corre el riesgo de perder mucha información. No obstante existen tecnicas de ***Under-sampling*** que logran manejar ello. La tecnica respectiva a utilizar es ***NearMiss***. Dicha tecnica, para atacar el problema de la pérdida potencial de información, propone el método del ***vecino cercano*** y sus variaciones. En la siguiente codigo, se aplica la tecnica mencionada sobre el conjunto de datos.

# %%
from imblearn.under_sampling import NearMiss
sampler = NearMiss(random_state=0)
X = df.drop(names[ind_clase], 1)
y = df[names[ind_clase]]
X_resampled, y_resampled = sampler.fit_resample(X, y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# Una vez aplicada la tecnica ***NearMiss***, se reconstruye el conjunto de datos reducido. Si bien las instancias de la clase ***Fraude (1)*** se mantienen, las instancias de la clase ***No fraude (0)*** han sido reducidas, aplicandose un muestreo enfocado en evitar la perdida de información. En el siguiente codigo, se imprime la cantidad de instancias por cada clase, siendo ***7,200*** instancias por clase, obteniendose lo propuesto.

# %%
dfcomplete = df.copy()
df_x = pd.DataFrame(X_resampled, columns = names[:-1])
df_y = pd.DataFrame(y_resampled, columns = [names[-1]])
df = pd.concat([df_x,df_y],axis=1)
df[names[ind_clase]].value_counts()
# Out:
# 1    7200
# 0    7200
# Name: fraud, dtype: int64

# %% [markdown]
# ##***4. Transformación de datos***

# %% [markdown]
# ###***A. Evaluación para normalización o estandarización de datos***

# %% [markdown]
# ####***A.1. Aplicación de normalización***

# %% [markdown]
# En el siguiente codigo, se aplica **normalización** sobre todos los datos del conjunto, excepto aquellos que correspondan a la columna clase o objetivo **Fraude (fraud)**. ***Esta parte del codigo no es del todo generica***, esto sucede, ya que se debe indicar el indice de la columna objetivo o clase. Luego de aplicar la tecnica, se imprime una descripción del conjunto de datos. ***Esta descripción muestra que todos los atributos poseen un rango de [0, 1].***

# %%
#Normalización de datos del dataset
ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
names = df.columns.values #Guardando el nombre de las columnas del dataset en un arreglo
dfn = df.copy()
for i in range(len(names)):
  if i != ind_clase:
    dfn[names[i]] = (df[names[i]] - df[names[i]].min())/ (df[names[i]].max()-df[names[i]].min())
dfn.describe()
# Out:
#                step      customer  ...        amount         fraud
# count  14400.000000  14400.000000  ...  14400.000000  14400.000000
# mean       0.495129      0.495332  ...      0.033933      0.500000
# std        0.290325      0.265680  ...      0.076977      0.500017
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        0.240223      0.244709  ...      0.003301      0.000000
# 50%        0.491620      0.526636  ...      0.007083      0.500000
# 75%        0.743017      0.715641  ...      0.038370      1.000000
# max        1.000000      1.000000  ...      1.000000      1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# ####***A.2. Aplicación de estandarización***

# %% [markdown]
# En el siguiente codigo, se aplica **estandarización** sobre todos los datos del conjunto, excepto aquellos que correspondan a la columna clase o objetivo **Fraude (fraud)**. ***Esta parte del codigo no es del todo generica***, esto sucede, ya que se debe indicar el indice de la columna objetivo o clase. Luego de aplicar la tecnica, se imprime una descripción del conjunto de datos. ***Esta descripción muestra que todos los atributos, excepto el atributo clase o objetivo, poseen una media de aproximadamente 0.***

# %%
#Estandarización de datos del dataset
ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
names = df.columns.values #Guardando el nombre de las columnas del dataset en un arreglo
dfe = df.copy()
for i in range(len(names)):
  if i != ind_clase:
    dfe[names[i]] = (df[names[i]] - df[names[i]].mean())/ df[names[i]].std()
dfe.describe()
# Out:
#                step      customer  ...        amount         fraud
# count  1.440000e+04  1.440000e+04  ...  1.440000e+04  14400.000000
# mean   2.713570e-16  4.069064e-16  ... -1.297072e-15      0.500000
# std    1.000000e+00  1.000000e+00  ...  1.000000e+00      0.500017
# min   -1.705429e+00 -1.864392e+00  ... -4.408166e-01      0.000000
# 25%   -8.780003e-01 -9.433252e-01  ... -3.979330e-01      0.000000
# 50%   -1.208671e-02  1.178240e-01  ... -3.488035e-01      0.500000
# 75%    8.538269e-01  8.292243e-01  ...  5.764866e-02      1.000000
# max    1.738983e+00  1.899529e+00  ...  1.255010e+01      1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# ####***A.3. Comparación y conclusión sobre la mejor técnica***

# %% [markdown]
# Se debe determinar cual es la mejor tecnica para este caso, ***normalización o estandarización***. Para ello, se utilizara la función ***prove***. Dicha función imprime la exactitud  promedio de 3 clasificadores ***(KNN, Arbol de decisión y SVM)***, realizando un muestreo de ***cross validation estratificado con k folds***, sobre los datos dados. La función se define a continuación.

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from numpy import *

def prove(df, nfols): #Función que desarrolla la prueba con clasificadores
  X = df.iloc[:,:-1].values #Caracteristicas
  Y = df.iloc[:,-1].values #Columna objetivo
  skf = StratifiedKFold(n_splits=nfols)
  knn = KNN(n_neighbors=5)
  dtree = DecisionTreeClassifier()
  svm = SVC()
  models = [knn, dtree, svm]
  scores = [0,0,0]
  for train_index, test_index in skf.split(X, Y):
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]
    for i in range(len(models)):
      models[i].fit(X_train, Y_train)
      predicciones = models[i].predict(X_test)
      scores[i] += accuracy_score(Y_test, predicciones)
  print("Puntuación total promedio: ", mean(scores)/nfols)

# %% [markdown]
# Ahora bien, se probaran los conjuntos de datos resultantes, despues de aplicadas las tecnicas de ***normalización o estandarización***. Para dicha prueba, se utilizara la función ***prove***, la cual se aplica sobre el conjunto de datos. Esto ultimo, nos permitira determinar con que tecnica se obtiene el conjunto de datos más apto para el proceso de clasificación.

# %% [markdown]
# A continuación, se prueba el conjunto de datos obtenido, despues de aplicada la tecnica de ***normalización***, con un muestreo de ***cross validation estratificado con k folds***, sobre los datos dados. En este caso ***k=20***. Luego de ello, se imprime la exactitud  total promedio obtenida.

# %%
prove(dfn, 20)
# Out:
# Puntuación total promedio:  0.9359490740740741

# %% [markdown]
# A continuación, se prueba el conjunto de datos obtenido, despues de aplicada la tecnica de ***estandarización***, con un muestreo de ***cross validation estratificado con k folds***, sobre los datos dados. En este caso ***k=20***. Luego de ello, se imprime la exactitud  total promedio obtenida.

# %%
prove(dfe, 20)
# Out:
# Puntuación total promedio:  0.9387962962962961

# %% [markdown]
# Con ***normalización***, se obtuvo un ***93.6%*** de exactitud  aproximadamente. Con ***estandarización***, se obtuvo un ***93.8%*** de exactitud aproximadamente. En ese sentido, es más conveniente trabajar con los datos ***estandarizados***. A continuación, se asigna que el conjunto de datos a usar tendra los datos ***estandarizados***.
#
# ***Conclusión: La estandarización de los datos, en este caso, permite obtener predicciones más exactas.***

# %%
df = dfe

# %% [markdown]
# ##***5. Feature Selection***

# %% [markdown]
# A continuación, se aplicara una serie de tecnicas de selección de caracteristicas y/o reducción de dimensionalidad sobre el conjunto de datos. Luego de la aplicación de cada técnica, se imprime el conjunto de datos resultante con las ***caracteristicas seleccionadas y el atributo objetivo***.

# %% [markdown]
# ###***A. Aplicación de Análisis de componentes principales (PCA)***

# %% [markdown]
# En el siguiente codigo, se esta implementando la aplicación de el ***Análisis de componentes principales (PCA)***. La técnica de ***PCA*** aplicada no solo reduce la dimensionalidad de los datos, sino que busca el numero de ***componentes principales optimo***, con los que se maximice el performance de los clasificadores. ***Esta parte del codigo no es del todo generica, ya que se debe indicar el indice de la columna clase o objetivo***. La columna clase o objetivo debe ser especificada con el objetivo de que no entre en el proceso de ***reducción de dimensionalidad***.

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_val_score

def dtree_score(X, Y): #Arbol de decisión y cross-validation con k=10
  dtree = DecisionTreeClassifier()
  return cross_val_score(dtree, X, Y, cv=10).mean()

def pca(df, clase): #Implementación de la técnica de pca
  names = df.columns.values
  y = df[names[clase]].values
  x = df.drop(names[clase], 1).values
  score = 0
  optimo_n = 2
  for n in range(len(names)-2, 1, -1): #Buscando el valor optimo para el numero de componentes principales de PCA
    pca = PCA(n_components=n)
    new_score = dtree_score(pca.fit_transform(x), y)
    if (score <= new_score):
      score = new_score
      optimo_n = n
  pca = PCA(n_components=optimo_n)
  df_x = pd.DataFrame(pca.fit_transform(x))
  df_y = df[names[clase]]
  df = pd.concat([df_x,df_y],axis=1)
  return df

ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
pcadf = pca(df, ind_clase)
pcadf.head()
# Out:
#           0         1         2         3         4  fraud
# 0  1.082191 -0.355819 -1.808205  1.047154  0.067382      0
# 1 -0.905259 -0.892679  0.631271 -0.896212 -0.666049      0
# 2 -0.900004 -0.913554  0.623455 -0.894115 -0.642249      0
# 3 -1.428368  0.189772 -0.050596 -0.375007  1.026579      0
# 4  1.653231  2.288822 -0.626034 -1.458967 -0.387678      0

# %% [markdown]
# ###***B. Aplicación de Método de filtrado con correlación de Pearson***

# %% [markdown]
# En el siguiente codigo, se esta implementando una técnica de ***Filtering***. Dicha tecnica corresponde a la aplicación de el ***Método de filtrado con correlación de Pearson***. ***Esta parte del codigo no es del todo generica, ya que se debe indicar el indice de la columna clase o objetivo***. La columna clase o objetivo debe ser especificada con el objetivo de que no entre en el proceso de ***selección de caracteristicas***

# %%
def filterpearson(df, clase): #Implementación de la técnica
  names = df.columns.values
  cor = df.corr()
  cor_target = abs(cor[names[clase]])
  peacols = []
  for i in range(len(names)):
    if (names[i] != names[clase] and cor_target[i] >= 0.11):
      peacols += [names[i]]
  df_x = df[peacols]
  df_y = df[names[clase]]
  df = pd.concat([df_x,df_y],axis=1)
  return df

ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
dffp = filterpearson(df, ind_clase)
dffp.head()
# Out:
#      gender  merchant  category    amount  fraud
# 0  1.176148  0.112970 -2.059185 -0.258553      0
# 1 -0.825570 -0.961731  0.711071 -0.424551      0
# 2 -0.825570 -0.961731  0.711071 -0.418219      0
# 3  1.176148 -0.961731  0.711071 -0.417034      0
# 4 -0.825570  1.270340 -1.782160 -0.346511      0

# %% [markdown]
# ###***C. Aplicación de Método Wrapper: Eliminación hacia atrás***

# %% [markdown]
# En el siguiente codigo, se esta implementando una técnica de ***Wrapper***. Dicha tecnica corresponde a la aplicación de el ***Método Wrapper: Eliminación hacia atrás***. ***Esta parte del codigo no es del todo generica, ya que se debe indicar el indice de la columna clase o objetivo***. La columna clase o objetivo debe ser especificada con el objetivo de que no entre en el proceso de ***selección de caracteristicas***.

# %%
import statsmodels.api as sm

#Eliminación hacia atras
def backwrapper(df, clase):
  X = df.drop(names[clase], 1) 
  Y = df[names[clase]]
  cols = list(X.columns)
  pmax = 1
  while (len(cols)>0):
    p= []
    X_1 = X[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(Y,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05): cols.remove(feature_with_p_max)
    else: break
  becols = cols
  df_x = df[becols]
  df_y = df[names[clase]]
  df = pd.concat([df_x,df_y],axis=1)
  return df

ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
dfbe = backwrapper(df, ind_clase)
dfbe.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#    customer    gender  merchant  category    amount  fraud
# 0  0.131558  1.176148  0.112970 -2.059185 -0.258553      0
# 1  1.146013 -0.825570 -0.961731  0.711071 -0.424551      0
# 2  1.146013 -0.825570 -0.961731  0.711071 -0.418219      0
# 3  1.146928  1.176148 -0.961731  0.711071 -0.417034      0
# 4 -1.297652 -0.825570  1.270340 -1.782160 -0.346511      0

# %% [markdown]
# ###***D. Aplicación de Método Wrapper: Eliminación de Característica Recursiva***

# %% [markdown]
# En el siguiente codigo, se esta implementando una técnica de ***Wrapper***. Dicha tecnica corresponde a la aplicación de el ***Método Wrapper: Eliminación de Característica Recursiva***. ***Esta parte del codigo no es del todo generica, ya que se debe indicar el indice de la columna clase o objetivo***. La columna clase o objetivo debe ser especificada con el objetivo de que no entre en el proceso de ***reducción de dimensionalidad***.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

def recursivewrapper(df, clase): #Implementación de la técnica
  names = df.columns.values
  X = df.drop(names[clase], 1) 
  Y = df[names[clase]]
  high_score=0
  nof=0
  for i in range(len(X.columns)):
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,i+1)
    X_train_rfe = rfe.fit_transform(X_train,Y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,Y_train)
    score = model.score(X_test_rfe,Y_test)
    if(score>high_score):
      high_score = score
      nof = i+1
  model = LinearRegression()
  rfe = RFE(model, nof)
  X_rfe = rfe.fit_transform(X,Y)
  model.fit(X_rfe,Y)
  temp = pd.Series(rfe.support_,index = X.columns)
  rfecols = temp[temp==True].index
  df_x = df[rfecols]
  df_y = df[names[clase]]
  df = pd.concat([df_x,df_y],axis=1)
  return df

ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
wradf = recursivewrapper(df, ind_clase)
wradf.head()
# Out:
#    customer    gender  merchant  category    amount  fraud
# 0  0.131558  1.176148  0.112970 -2.059185 -0.258553      0
# 1  1.146013 -0.825570 -0.961731  0.711071 -0.424551      0
# 2  1.146013 -0.825570 -0.961731  0.711071 -0.418219      0
# 3  1.146928  1.176148 -0.961731  0.711071 -0.417034      0
# 4 -1.297652 -0.825570  1.270340 -1.782160 -0.346511      0

# %% [markdown]
# ###***E. Aplicación de Método embebido***

# %% [markdown]
# En el siguiente codigo, se esta implementando una técnica de ***Embedded***. Dicha tecnica corresponde a la aplicación de el ***Método de embebido***. ***Esta parte del codigo no es del todo generica, ya que se debe indicar el indice de la columna clase o objetivo***. La columna clase o objetivo debe ser especificada con el objetivo de que no entre en el proceso de ***reducción de dimensionalidad***.

# %%
from sklearn.linear_model import LassoCV

def embebido(df, clase): #Implementación de la técnica
  names = df.columns.values
  X = df.drop(names[clase], 1) 
  Y = df[names[clase]]
  reg = LassoCV()
  reg.fit(X, Y)
  coef = pd.Series(reg.coef_, index = X.columns)
  embbcols = coef[abs(coef) > 0].index
  df_x = df[embbcols]
  df_y = df[names[clase]]
  df = pd.concat([df_x,df_y],axis=1)
  return df

ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
emdf = embebido(df, ind_clase)
emdf.head()
# Out:
#      gender  category    amount  fraud
# 0  1.176148 -2.059185 -0.258553      0
# 1 -0.825570  0.711071 -0.424551      0
# 2 -0.825570  0.711071 -0.418219      0
# 3  1.176148  0.711071 -0.417034      0
# 4 -0.825570 -1.782160 -0.346511      0

# %% [markdown]
# ###***F. Aplicación de Árboles extremadamente aleatorizados (Extra Tree Classifier) para selección de caracteristicas***

# %% [markdown]
# En el siguiente codigo, se esta implementando una técnica que corresponde a la aplicación de ***Árboles extremadamente aleatorizados (Extra Tree Classifier) para selección de caracteristicas***. ***Esta parte del codigo no es del todo generica, ya que se debe indicar el indice de la columna clase o objetivo***. La columna clase o objetivo debe ser especificada con el objetivo de que no entre en el proceso de ***selección de caracteristicas***.

# %%
from sklearn.ensemble import ExtraTreesClassifier

def xtreec(df, clase):
  names = df.columns.values
  X = df.drop(names[clase], 1) 
  Y = df[names[clase]]
  model = ExtraTreesClassifier()
  model.fit(X,Y)
  feat_importances = pd.Series(model.feature_importances_, index=X.columns)
  ficols = feat_importances[feat_importances > 0.1].index
  df_x = df[ficols]
  df_y = df[names[clase]]
  df = pd.concat([df_x,df_y],axis=1)
  return df

ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
xtdf = xtreec(df, ind_clase)
xtdf.head()
# Out:
#    merchant  category    amount  fraud
# 0  0.112970 -2.059185 -0.258553      0
# 1 -0.961731  0.711071 -0.424551      0
# 2 -0.961731  0.711071 -0.418219      0
# 3 -0.961731  0.711071 -0.417034      0
# 4  1.270340 -1.782160 -0.346511      0

# %% [markdown]
# ###***G. Aplicación de Selección Univariante***

# %% [markdown]
# En el siguiente codigo, se esta implementando una técnica que corresponde a la aplicación de ***Selección Univariante***. Las pruebas estadísticas se pueden usar para seleccionar aquellas características que tienen la relación más fuerte con la variable objetivo. Por ejemplo, el método ***ANOVA*** de valor ***F*** es apropiado para entradas numéricas y datos categóricos. ***Esta parte del codigo no es del todo generica, ya que se debe indicar el indice de la columna clase o objetivo***. La columna clase o objetivo debe ser especificada con el objetivo de que no entre en el proceso de ***reducción de dimensionalidad***.

# %%
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import heapq

def univar(df, clase): #Implementación de la tecnica
  names = df.columns.values
  X = df.drop(names[clase], 1) 
  Y = df[names[clase]]
  test = SelectKBest(score_func=f_classif, k=4)
  fit = test.fit(X, Y)
  set_printoptions(precision=3)
  scores = pd.Series(fit.scores_, index=X.columns)
  ucols = scores[heapq.nlargest(5, range(len(scores)), scores.__getitem__)].index
  df_x = df[ucols]
  df_y = df[names[clase]]
  df = pd.concat([df_x,df_y],axis=1)
  return df

ind_clase = 7 #Se debe indicar el indice de la columna clase o objetivo
uvdf = univar(df, ind_clase)
uvdf.head()
# Out:
#      amount  category  merchant    gender  customer  fraud
# 0 -0.258553 -2.059185  0.112970  1.176148  0.131558      0
# 1 -0.424551  0.711071 -0.961731 -0.825570  1.146013      0
# 2 -0.418219  0.711071 -0.961731 -0.825570  1.146013      0
# 3 -0.417034  0.711071 -0.961731  1.176148  1.146928      0
# 4 -0.346511 -1.782160  1.270340 -0.825570 -1.297652      0

# %% [markdown]
# ###***H. Comparación y Conclusión sobre la mejor técnica***

# %% [markdown]
# En esta parte, se evaluara que tecnica de ***selección de caracteristicas*** tiene mejor efecto en la exactitud  de los clasificadores. Para dicha evaluación, se utilizara una función llamada ***prove***. Esta función promedia la exactitud de 3 clasificadores ***(KNN, Arbol de decisión y SVM)***, realizando un muestreo de ***cross validation estratificado con k folds***, sobre los datos dados. En este caso ***k=15***. La función ***prove*** sera aplicada sobre cada conjunto de datos obtenido con cada tecnica de selección. La tecnica que de mejores resultados sera utilizada.

# %% [markdown]
# A continuación, se imprime la exactitud obtenida, aplicando la tecnica de ***Analisis de Componenetes Principales (PCA)***.

# %%
prove(pcadf, 15)
# Out:
# Puntuación total promedio:  0.8883564814814815

# %% [markdown]
# Ahora bien, se imprime la exactitud obtenida, aplicando la tecnica de ***Filtrado con correlación de Pearson***.

# %%
prove(dffp,15)
# Out:
# Puntuación total promedio:  0.962037037037037

# %% [markdown]
# Se imprime la exactitud obtenida, aplicando la tecnica de ***Wrapper: Eliminación hacia atrás***.

# %%
prove(dfbe, 15)
# Out:
# Puntuación total promedio:  0.9609027777777778

# %% [markdown]
# A continuación, se imprime la exactitud obtenida, aplicando la tecnica de ***Wrapper: Eliminación de Característica Recursiva***.

# %%
prove(wradf, 15)
# Out:
# Puntuación total promedio:  0.9603472222222222

# %% [markdown]
# Con el siguiente codigo, se imprime la exactitud obtenida, aplicando el ***Método Embebido***.

# %%
prove(emdf, 15)
# Out:
# Puntuación total promedio:  0.9471296296296295

# %% [markdown]
# Ahora bien, se imprime la exactitud obtenida, aplicando la tecnica de ***Árboles extremadamente aleatorizados (Extra Tree Classifier) para selección de caracteristicas***.

# %%
prove(xtdf, 15)
# Out:
# Puntuación total promedio:  0.9654398148148148

# %% [markdown]
# Se imprime la exactitud obtenida, aplicando la tecnica de ***Selección Univariante***.

# %%
prove(uvdf, 15)
# Out:
# Puntuación total promedio:  0.9607407407407408

# %% [markdown]
# A continuación, se muestra una tabla con los resultados obtenidos para cada tecnica de ***selección de caracteristicas y/o reducción de dimensionalidad*** aplicada.
#
# ![alt text](https://i.ibb.co/442YVcb/tabla-reducdim.png)
#
# Como se puede apreciar, el ***Método de Árboles extremadamente aleatorizados*** ha logrado obtener la mejor exactitud promedio, con la menor cantidad de caracteristicas, dada la evaluación realizada. La exactitud promedio alacanzada es de ***96.5%***. A continuación, se asigna que el conjunto de datos a usar tendra solo las **3 caracteristicas** seleccionadas por el ***Método de Árboles extremadamente aleatorizados***. Aparte de dichas caracteristicas, tambien se contara con la columna clase o objetivo ***Fraude (fraud)***. Se debe resaltar que las caracteristicas finales seleccionadas y más relevantes son ***Comerciante (merchant)***, ***Categoria (category)*** y ***Cantidad (amount)***.

# %%
df = xtdf
df.head()
# Out:
#    merchant  category    amount  fraud
# 0  0.112970 -2.059185 -0.258553      0
# 1 -0.961731  0.711071 -0.424551      0
# 2 -0.961731  0.711071 -0.418219      0
# 3 -0.961731  0.711071 -0.417034      0
# 4  1.270340 -1.782160 -0.346511      0

# %% [markdown]
# #***III. Prueba con Clasificadores***

# %% [markdown]
# ##***1. Análisis de hiperparámetros con métricas de desempeño***

# %% [markdown]
# En esta parte, se debe seleccionar ***6*** algoritmos de aprendizaje supervisado, los cuales seran utilizados para trabajar el conjunto de datos respectivo. Se evaluaran los diferentes valores que pueden tomar los hiperparametros de cada algoritmo de aprendizaje supervisado, con el objetivo de encontrar aquellos que maximizen el desempeño de clasificación. Para la evaluación, se utilizaran metricas de desempeño como ***exactitud, precisión, recall, F1, y las curvas ROC***. Asimismo, para el muestreo respecto a la selección de datos de prueba y entrenamiento, se aplicara ***cross-validation estratificado***. Ahora bien, los algoritmos seleccionados son ***K Vecinos más Cercanos (KNN), Árboles de Decisión, Máquinas de Vectores de Soporte (SVM), Random Forest, Regresión Logistica (Logistic Regression) y Redes Bayesianas Multinomiales (Multinomial Naive Bayes)***.

# %% [markdown]
# En el siguiente codigo, se implementa la función ***test_model***, la cual tiene como objetivo permitir probar un modelo de clasficación con el conjunto de datos dado. Esta evaluación se hace con ***cross-validation estratificado*** dado un numero de folds. La parte interesante de esta función es que retorna distintas metricas de evaluación, tales como ***exactitud, precisión, recall, F1 y Área bajo la curva ROC (AUC)***.

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import roc_auc_score

def test_model(model, df, nfols): #Implementación de función para probar modelo con metricas
  X = df.iloc[:,:-1].values #Caracteristicas
  Y = df.iloc[:,-1].values #Columna objetivo
  skf = StratifiedKFold(n_splits=nfols)
  acuracym = 0 #Exactitud
  precisionm = 0 #Precisión
  recallm = 0 #Recall
  f1m = 0 #F1
  aucm = 0 #Area bajo la curva ROC
  for train_index, test_index in skf.split(X, Y): #Cross-validation estratificado con k folds
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]
    model.fit(X_train, Y_train)
    predicciones = model.predict(X_test)
    acuracym += accuracy_score(Y_test, predicciones)
    precision, recall, f1, support = precision_recall_fscore_support(Y_test, predicciones, average='binary', zero_division=0)
    precisionm += precision
    recallm += recall
    f1m += f1
    aucm += roc_auc_score(Y_test, model.predict_proba(X_test)[::,1])
  return acuracym/nfols, precisionm/nfols, recallm/nfols, f1m/nfols, aucm/nfols

# %% [markdown]
# ###***A. K Vecinos más Cercanos (KNN)***

# %% [markdown]
# Se procedera a realizar el ajuste de hiperparametros para ***KNN*** con el conjunto de datos dado. Con respecto a dicho ajuste, nos enfocaremos en ***3 hiperparametros*** principalmente, los cuales son ***Numero de vecinos (n_neighbors), Pesos (weights) y Algoritmo (algorithm)***. Estos seran ajustados, ya que son considerados los más importantes. Se tratara de buscar la combinación de estos ***hiperparametros*** que maximize la performance de clasficación. Se aplicara ***cross-validation estratificado con K=10*** para el muestreo. La evaluación de cada combinación de ***hiperparametros*** se realizá con la función ***test_model***. Llegados a este punto, se procedera a describir a los ***hiperparametros***:
#
# * ***Numero de vecinos (n_neighbors): Número de vecinos a usar por defecto para consultas de vecinos.***
#
# * ***Pesos (weights): Función de peso utilizada en predicción, la cual puede ser Uniforme (uniform) o de Distancia (distance).***
#
# * ***Algoritmo (algorithm): Algoritmo utilizado para calcular los vecinos más cercanos. Este algoritmo puede ser Ball tree, KD tree, Fuerza bruta (brute) y Automatico (auto).***

# %% [markdown]
# En el siguiente codigo, respecto a la busqueda de los mejores hiperparametros, no se estan evaluando todas las posibilidades. Esto ultimo ocurre principalmente con el ***Numero de vecinos (n_neighbors)***. En este caso, lo que se propone es primero realizar una búsqueda general rápida, con el objetivo de ubicar, aproximadamente, el rango en el que se podría encontrar el ***hiperparametro*** óptimo. Una vez ubicado dicho rango, proceder con una búsqueda exhaustiva. Además, se almacena el ***promedio de las metricas*** obtenidas, por cada combinación de ***hiperparametros*** evaluada, en un arreglo. Con dicho promedio, se logra considerar la optimización de todas las metricas en la busqueda de los ***hiperparametros***.

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

#Hiperparametros:
n_neigbs = [10, 50, 100, 150, 200] 
weigs = ['uniform', 'distance']
algort = ['auto', 'ball_tree', 'kd_tree', 'brute']

knnallp = [] #Arreglo para guardar el promedio de todas las metricas
knnmods = [] #Arreglo para guardar los modelos ajustados

for n in n_neigbs: #Busqueda de hiperparametros
  for w in weigs:
    for al in algort:
      knn = KNN(n_neighbors=n, weights=w, algorithm=al)
      acc, pre, rec, f1, auc = test_model(knn, df, 10)
      knnallp.append((acc+pre+rec+f1+auc)/5)
      knnmods.append(knn)

# %% [markdown]
# Con la evaluación ***test_model***, se consideran una serie de metricas, las cuales son promediadas y almacenadas durante la busqueda. En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(knnallp).argsort()[-1] #Indice del mejor modelo
bestmodel = knnmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", knnallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de vecinos (n_neighbors): ", bestmodel.get_params()['n_neighbors'])
print("Pesos (weights): ", bestmodel.get_params()['weights'])
print("Algoritmo (algorithm): ", bestmodel.get_params()['algorithm'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9770210310925727
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de vecinos (n_neighbors):  10
# Pesos (weights):  uniform
# Algoritmo (algorithm):  auto

# %% [markdown]
# De acuerdo a lo obtenido anteriormente, con respecto a el ***Numero de vecinos (n_neighbors)***, se logra identificar que el mejor valor para dicho ***hiperparametro*** es cercano a ***10***. En ese sentido, se reducira el rango a **[1, 20]**, y se procedera a realizar una busqueda exhaustiva. Cabe mencionar que se almacenan las metricas obtenidas y el promedio de dichas metricas, por cada combinación de ***hiperparametros*** evaluada, en arreglos.

# %%
#Hiperparametros: 
n_neigbs = [i for i in range(1,21)]
weigs = ['uniform', 'distance']
algort = ['auto', 'ball_tree', 'kd_tree', 'brute']

knnacc = [] #Arreglo para guardar exactitudes
knnpre = [] #Arreglo para guardar precisiones
knnrec = [] #Arreglo para guardar recalls
knnf1 = [] #Arreglo para guardar F1s
knnauc = [] #Arreglo para guardar AUCs
knnallp = [] #Arreglo para guardar el promedio de todas las metricas
knnmods = [] #Arreglo para guardar los modelos ajustados

for n in n_neigbs: #Busqueda de hiperparametros
  for w in weigs:
    for al in algort:
      knn = KNN(n_neighbors=n, weights=w, algorithm=al)
      acc, pre, rec, f1, auc = test_model(knn, df, 10)
      knnacc.append(acc)
      knnpre.append(pre)
      knnrec.append(rec)
      knnf1.append(f1)
      knnauc.append(auc)
      knnallp.append((acc+pre+rec+f1+auc)/5)
      knnmods.append(knn)

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(knnallp).argsort()[-1] #Indice del mejor modelo
bestmodel = knnmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", knnallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de vecinos (n_neighbors): ", bestmodel.get_params()['n_neighbors'])
print("Pesos (weights): ", bestmodel.get_params()['weights'])
print("Algoritmo (algorithm): ", bestmodel.get_params()['algorithm'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9777843134193013
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de vecinos (n_neighbors):  15
# Pesos (weights):  uniform
# Algoritmo (algorithm):  brute

# %% [markdown]
# Ahora bien, considerando el promedio de todas las metricas evaluadas, se logra definir los ***hiperparametros*** señalados anteriormente como los mejores. No obstante, ello puede cambiar si se analiza desde la perspectiva de cada metrica. Por lo tanto, se procedera a indicar el maximo valor obtenido de cada metrica, durante la busqueda, y los ***hiperparametros*** que permiten alcanzar dicho valor.

# %% [markdown]
# ####***A.1. Mejores hiperparametros según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Exactitud (Accuracy)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(knnacc).argsort()[-1] #Indice del mejor modelo
bestmodel = knnmods[idx]
print("Mejor Exactitud (Accuracy) obtenida en la busqueda: ", knnacc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de vecinos (n_neighbors): ", bestmodel.get_params()['n_neighbors'])
print("Pesos (weights): ", bestmodel.get_params()['weights'])
print("Algoritmo (algorithm): ", bestmodel.get_params()['algorithm'])
# Out:
# Mejor Exactitud (Accuracy) obtenida en la busqueda:  0.9733333333333333
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de vecinos (n_neighbors):  15
# Pesos (weights):  uniform
# Algoritmo (algorithm):  brute

# %% [markdown]
# ####***A.2. Mejores hiperparametros según metrica de Precisión (precision)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Precisión (precision)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(knnpre).argsort()[-1] #Indice del mejor modelo
bestmodel = knnmods[idx]
print("Mejor Precisión (precision) obtenida en la busqueda: ", knnpre[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de vecinos (n_neighbors): ", bestmodel.get_params()['n_neighbors'])
print("Pesos (weights): ", bestmodel.get_params()['weights'])
print("Algoritmo (algorithm): ", bestmodel.get_params()['algorithm'])
# Out:
# Mejor Precisión (precision) obtenida en la busqueda:  0.9750856242874807
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de vecinos (n_neighbors):  2
# Pesos (weights):  uniform
# Algoritmo (algorithm):  kd_tree

# %% [markdown]
# ####***A.3. Mejores hiperparametros según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***Recall*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(knnrec).argsort()[-1] #Indice del mejor modelo
bestmodel = knnmods[idx]
print("Mejor Recall obtenido en la busqueda: ", knnrec[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de vecinos (n_neighbors): ", bestmodel.get_params()['n_neighbors'])
print("Pesos (weights): ", bestmodel.get_params()['weights'])
print("Algoritmo (algorithm): ", bestmodel.get_params()['algorithm'])
# Out:
# Mejor Recall obtenido en la busqueda:  0.981111111111111
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de vecinos (n_neighbors):  19
# Pesos (weights):  uniform
# Algoritmo (algorithm):  kd_tree

# %% [markdown]
# ####***A.4. Mejores hiperparametros según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***F1*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(knnf1).argsort()[-1] #Indice del mejor modelo
bestmodel = knnmods[idx]
print("Mejor F1 obtenido en la busqueda: ", knnf1[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de vecinos (n_neighbors): ", bestmodel.get_params()['n_neighbors'])
print("Pesos (weights): ", bestmodel.get_params()['weights'])
print("Algoritmo (algorithm): ", bestmodel.get_params()['algorithm'])
# Out:
# Mejor F1 obtenido en la busqueda:  0.9735397068456088
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de vecinos (n_neighbors):  15
# Pesos (weights):  uniform
# Algoritmo (algorithm):  brute

# %% [markdown]
# ####***A.5. Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Área bajo la curva ROC (AUC)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(knnauc).argsort()[-1] #Indice del mejor modelo
bestmodel = knnmods[idx]
print("Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda: ", knnauc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de vecinos (n_neighbors): ", bestmodel.get_params()['n_neighbors'])
print("Pesos (weights): ", bestmodel.get_params()['weights'])
print("Algoritmo (algorithm): ", bestmodel.get_params()['algorithm'])
# Out:
# Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda:  0.9953855131172841
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de vecinos (n_neighbors):  20
# Pesos (weights):  uniform
# Algoritmo (algorithm):  kd_tree

# %% [markdown]
# ####***A.6. Comparación y Síntesis***

# %% [markdown]
# En esta parte, se procedera a realizar la síntesis o resumen de los resultados obtenidos. Se empleara una comparación entre los mismos, con el objetivo de formular conclusiones apropiadas. La evaluación se desarrolla en base a distintas metricas. Entre ellas, cabe mencionar ***Exactitud, Precisión, Recall, F1 y Área bajo la curva ROC (AUC)***. Asimismo, tambien se usa el ***Promedio de métricas***, el cual constituye el promedio de los valores de todas las metricas mencionadas. Dicho promedio fue planteado con el objetivo de considerar la maximización de todas las metricas en la busqueda de los mejores hiperparametros. En la siguiente tabla, se presentan los ***hiperparametros*** que maximizan los valores de cada metrica. En ese sentido, ello permite identificar los mejores ***hiperparametros*** en base a que medida se desee optimizar.
#
# ![Tabla de resumen hiperparametros](https://i.ibb.co/CMZnxqr/tablaknnhip.png)
#
# Respecto a los resultados obtenidos en la tabla anterior, es factible mencionar que el mejor valor para el ***hiperparametro Pesos (weights)*** es ***Uniform***. Además, con respecto a los valores de los ***hiperparametros Numero de vecinos (n_neighbors)*** y ***Algoritmo (algorithm)***, estos se repiten y coinciden para ***3 metricas*** en la tabla, las cuales son ***F1, Exactitud*** y ***Promedio de metricas***. Es posible argumentar que ***F1*** sirve como punto de equilibrio y engloba a ***Precisión*** y ***Recall***. Por lo tanto, se concluye que los ***hiperparametros*** que logran maximizar las metricas de forma conjunta y funcionan mejor con los datos son:
#
# * ***Numero de vecinos (n_neighbors): 15***
# * ***Pesos (weights): Uniform***
# * ***Algoritmo (algorithm): Brute***

# %% [markdown]
# Continuando con el asunto, se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***KNN*** sobre el conjunto de datos. Para dicho modelo se tomara en cuenta los ***hiperparametros*** mencionados anteriormente. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. Para dibujar las curvas ***ROC***, se utiliza la función ***draw_rocs***. Por otro lado, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

def draw_rocs(model, df, nfols): #Implementación de función para dibujar ROC
  X = df.iloc[:,:-1].values #Caracteristicas
  Y = df.iloc[:,-1].values #Columna objetivo
  skf = StratifiedKFold(n_splits=nfols)
  i = 1
  for train_index, test_index in skf.split(X, Y): #Cross-validation estratificado con k folds
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]
    model.fit(X_train, Y_train)
    y_pred_proba = model.predict_proba(X_test)[::,1]
    fpr, tpr, _ = roc_curve(Y_test,  y_pred_proba)
    auc = roc_auc_score(Y_test, y_pred_proba)
    plt.plot(fpr,tpr,label="Fold " + str(i)+", auc="+str(auc))
    i = i + 1
  plt.legend(loc=4)
  plt.show()

# %%
idx = np.array(knnallp).argsort()[-1] #Indice del mejor modelo
bestmodel = knnmods[idx]

draw_rocs(bestmodel, df, 10)

# %% [markdown]
# ###***B. Arbol de Decisión***

# %% [markdown]
# Se procedera a realizar el ajuste de hiperparametros para ***Arbol de Decisión*** con el conjunto de datos dado. Con respecto a dicho ajuste, nos enfocaremos en ***4 hiperparametros*** principalmente, los cuales son ***Maxima profundidad (max_depth), min_samples_split, min_samples_leaf y max_features***. Estos seran ajustados, ya que son considerados los más importantes. Se tratara de buscar la combinación de estos ***hiperparametros*** que maximize la performance de clasficación. Se aplicara ***cross-validation estratificado con K=10*** para el muestreo. La evaluación de cada combinación de ***hiperparametros*** se realizá con la función ***test_model***. Llegados a este punto, se procedera a describir a los ***hiperparametros***:
#
# * ***Maxima profundidad (max_depth): La profundidad máxima del árbol.***
#
# * ***min_samples_split: El número mínimo de muestras requeridas para dividir un nodo interno.***
#
# * ***min_samples_leaf: El número mínimo de muestras necesarias para estar en un nodo hoja.***
#
# * ***max_features: La cantidad de características a considerar cuando se busca la mejor división. Entre las posibilidades, se cuenta con Raíz (sqrt), Logaritmo (log2) y Ninguno de los anteriores (None).***

# %% [markdown]
# En el siguiente codigo, respecto a la busqueda de los mejores hiperparametros, no se estan evaluando todas las posibilidades. En este caso, lo que se propone es primero realizar una búsqueda general rápida, con el objetivo de ubicar, aproximadamente, el rango en el que se podría encontrar el ***hiperparametro*** óptimo. Una vez ubicado dicho rango, proceder con una búsqueda exhaustiva. Además, se almacena el ***promedio de las metricas*** obtenidas, por cada combinación de ***hiperparametros*** evaluada, en un arreglo. Con dicho promedio, se logra considerar la optimización de todas las metricas en la busqueda de los ***hiperparametros***.

# %%
from sklearn.tree import DecisionTreeClassifier

#Hiperparametros:
maxdepts = [5, 10, 30, 50, 100]
mssplits = [2, 0.1, 0.3, 0.6, 0.8]
msleafs = [0.1, 0.3, 0.5]
mfeats = ['sqrt','log2',None]

dtcallp = [] #Arreglo para guardar el promedio de todas las metricas
dtcmods = [] #Arreglo para guardar los modelos ajustados

for d in maxdepts: #Busqueda de hiperparametros
  for s in mssplits:
    for l in msleafs:
      for f in mfeats: 
        dtc = DecisionTreeClassifier(max_depth=d, min_samples_split=s, min_samples_leaf=l, max_features=f)
        acc, pre, rec, f1, auc = test_model(dtc, df, 10)
        dtcallp.append((acc+pre+rec+f1+auc)/5)
        dtcmods.append(dtc)

# %% [markdown]
# Con la evaluación ***test_model***, se consideran una serie de metricas, las cuales son promediadas y almacenadas durante la busqueda. En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(dtcallp).argsort()[-1] #Indice del mejor modelo
bestmodel = dtcmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", dtcallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Maxima profundidad (max_depth): ", bestmodel.get_params()['max_depth'])
print("min_samples_split: ", bestmodel.get_params()['min_samples_split'])
print("min_samples_leaf: ", bestmodel.get_params()['min_samples_leaf'])
print("max_features: ", bestmodel.get_params()['max_features'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9270808116667485
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Maxima profundidad (max_depth):  30
# min_samples_split:  0.1
# min_samples_leaf:  0.1
# max_features:  None

# %% [markdown]
# De acuerdo a lo obtenido anteriormente, con respecto a la ***Maxima profundidad (max_depth)***, se logra identificar que el mejor valor para dicho ***hiperparametro*** es cercano a ***30***. En ese sentido, se reducira el rango a **[10, 40]**. Ahora bien, con respecto a ***min_samples_split***, el mejor valor se aproxima a ***0.1***. Por lo tanto, el rango, en este caso, sera reducido a **[0, 0.2]**. Igualmente, el mejor valor para ***min_samples_leaf*** es cercano a ***0.1***, por lo que el rango respectivo sera reducido a **[0, 0.2]**. Teniendo en cuento estos rangos, se procedera a realizar una busqueda exhaustiva. Cabe mencionar que se almacenan las metricas obtenidas y el promedio de dichas metricas, por cada combinación de ***hiperparametros*** evaluada, en arreglos.

# %%
#Hiperparametros:
maxdepts = [i for i in range(10,40)]
mssplits = [i*0.01 for i in range(1, 20, 2)]
msleafs = [i*0.01 for i in range(1, 20, 2)]
mfeats = ['sqrt','log2',None]

dtcacc = [] #Arreglo para guardar exactitudes
dtcpre = [] #Arreglo para guardar precisiones
dtcrec = [] #Arreglo para guardar recalls
dtcf1 = [] #Arreglo para guardar F1s
dtcauc = [] #Arreglo para guardar AUCs
dtcallp = [] #Arreglo para guardar el promedio de todas las metricas
dtcmods = [] #Arreglo para guardar los modelos ajustados

for d in maxdepts: #Busqueda de hiperparametros
  for s in mssplits:
    for l in msleafs:
      for f in mfeats: 
        dtc = DecisionTreeClassifier(max_depth=d, min_samples_split=s, min_samples_leaf=l, max_features=f)
        acc, pre, rec, f1, auc = test_model(dtc, df, 10)
        dtcacc.append(acc)
        dtcpre.append(pre)
        dtcrec.append(rec)
        dtcf1.append(f1)
        dtcauc.append(auc)
        dtcallp.append((acc+pre+rec+f1+auc)/5)
        dtcmods.append(dtc)

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(dtcallp).argsort()[-1] #Indice del mejor modelo
bestmodel = dtcmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", dtcallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Maxima profundidad (max_depth): ", bestmodel.get_params()['max_depth'])
print("min_samples_split: ", bestmodel.get_params()['min_samples_split'])
print("min_samples_leaf: ", bestmodel.get_params()['min_samples_leaf'])
print("max_features: ", bestmodel.get_params()['max_features'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9646966207315447
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Maxima profundidad (max_depth):  16
# min_samples_split:  0.03
# min_samples_leaf:  0.01
# max_features:  log2

# %% [markdown]
# Ahora bien, considerando el promedio de todas las metricas evaluadas, se logra definir los ***hiperparametros*** señalados anteriormente como los mejores. No obstante, ello puede cambiar si se analiza desde la perspectiva de cada metrica. Por lo tanto, se procedera a indicar el maximo valor obtenido de cada metrica, durante la busqueda, y los ***hiperparametros*** que permiten alcanzar dicho valor.

# %% [markdown]
# ####***B.1. Mejores hiperparametros según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Exactitud (Accuracy)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(dtcacc).argsort()[-1] #Indice del mejor modelo
bestmodel = dtcmods[idx]
print("Mejor Exactitud (Accuracy) obtenida en la busqueda: ", dtcacc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Maxima profundidad (max_depth): ", bestmodel.get_params()['max_depth'])
print("min_samples_split: ", bestmodel.get_params()['min_samples_split'])
print("min_samples_leaf: ", bestmodel.get_params()['min_samples_leaf'])
print("max_features: ", bestmodel.get_params()['max_features'])
# Out:
# Mejor Exactitud (Accuracy) obtenida en la busqueda:  0.9579166666666667
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Maxima profundidad (max_depth):  16
# min_samples_split:  0.03
# min_samples_leaf:  0.01
# max_features:  log2

# %% [markdown]
# ####***B.2. Mejores hiperparametros según metrica de Precisión (precision)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Precisión (precision)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(dtcpre).argsort()[-1] #Indice del mejor modelo
bestmodel = dtcmods[idx]
print("Mejor Precisión (precision) obtenida en la busqueda: ", dtcpre[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Maxima profundidad (max_depth): ", bestmodel.get_params()['max_depth'])
print("min_samples_split: ", bestmodel.get_params()['min_samples_split'])
print("min_samples_leaf: ", bestmodel.get_params()['min_samples_leaf'])
print("max_features: ", bestmodel.get_params()['max_features'])
# Out:
# Mejor Precisión (precision) obtenida en la busqueda:  0.9602858133235372
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Maxima profundidad (max_depth):  39
# min_samples_split:  0.15
# min_samples_leaf:  0.07
# max_features:  sqrt

# %% [markdown]
# ####***B.3. Mejores hiperparametros según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***Recall*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(dtcrec).argsort()[-1] #Indice del mejor modelo
bestmodel = dtcmods[idx]
print("Mejor Recall obtenido en la busqueda: ", dtcrec[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Maxima profundidad (max_depth): ", bestmodel.get_params()['max_depth'])
print("min_samples_split: ", bestmodel.get_params()['min_samples_split'])
print("min_samples_leaf: ", bestmodel.get_params()['min_samples_leaf'])
print("max_features: ", bestmodel.get_params()['max_features'])
# Out:
# Mejor Recall obtenido en la busqueda:  0.9905555555555556
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Maxima profundidad (max_depth):  28
# min_samples_split:  0.05
# min_samples_leaf:  0.01
# max_features:  sqrt

# %% [markdown]
# ####***B.4. Mejores hiperparametros según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***F1*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(dtcf1).argsort()[-1] #Indice del mejor modelo
bestmodel = dtcmods[idx]
print("Mejor F1 obtenido en la busqueda: ", dtcf1[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Maxima profundidad (max_depth): ", bestmodel.get_params()['max_depth'])
print("min_samples_split: ", bestmodel.get_params()['min_samples_split'])
print("min_samples_leaf: ", bestmodel.get_params()['min_samples_leaf'])
print("max_features: ", bestmodel.get_params()['max_features'])
# Out:
# Mejor F1 obtenido en la busqueda:  0.9585957672086736
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Maxima profundidad (max_depth):  16
# min_samples_split:  0.03
# min_samples_leaf:  0.01
# max_features:  log2

# %% [markdown]
# ####***B.5. Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Área bajo la curva ROC (AUC)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(dtcauc).argsort()[-1] #Indice del mejor modelo
bestmodel = dtcmods[idx]
print("Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda: ", dtcauc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Maxima profundidad (max_depth): ", bestmodel.get_params()['max_depth'])
print("min_samples_split: ", bestmodel.get_params()['min_samples_split'])
print("min_samples_leaf: ", bestmodel.get_params()['min_samples_leaf'])
print("max_features: ", bestmodel.get_params()['max_features'])
# Out:
# Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda:  0.9892574266975309
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Maxima profundidad (max_depth):  11
# min_samples_split:  0.01
# min_samples_leaf:  0.01
# max_features:  None

# %% [markdown]
# ####***B.6. Comparación y Síntesis***

# %% [markdown]
# En esta parte, se procedera a realizar la síntesis o resumen de los resultados obtenidos. Se empleara una comparación entre los mismos, con el objetivo de formular conclusiones apropiadas. La evaluación se desarrolla en base a distintas metricas. Entre ellas, cabe mencionar ***Exactitud, Precisión, Recall, F1 y Área bajo la curva ROC (AUC)***. Asimismo, tambien se usa el ***Promedio de métricas***, el cual constituye el promedio de los valores de todas las metricas mencionadas. Dicho promedio fue planteado con el objetivo de considerar la maximización de todas las metricas en la busqueda de los mejores ***hiperparametros***. En la siguiente tabla, se presentan los ***hiperparametros*** que maximizan los valores de cada metrica. En ese sentido, ello permite identificar los mejores ***hiperparametros*** en base a que medida se desee optimizar.
#
# ![Tabla de resumen hiperparametros](https://i.ibb.co/28SK6sN/tabladtchip.png)
#
# Respecto a los resultados obtenidos en la tabla anterior, es factible mencionar que el mejor valor para el ***hiperparametro max_features*** es ***Logaritmo***. Se concluye lo anterior, ya que para la mayoria de metricas, ***Logaritmo (log2)*** es el valor que mejor funciona. Además, con respecto a los valores de los ***hiperparametros Maxima profundidad (max_depth)***, ***min_samples_split*** y ***min_samples_leaf***, estos se repiten y coinciden para ***3 metricas*** en la tabla, las cuales son ***F1, Exactitud*** y ***Promedio de metricas***. Es posible argumentar que ***F1*** sirve como punto de equilibrio y engloba a ***Precisión*** y ***Recall***. Por lo tanto, se concluye que los ***hiperparametros*** que logran maximizar las metricas de forma conjunta y funcionan mejor con los datos son:
#
# * ***Maxima profundidad (max_depth): 16***
# * ***min_samples_split: 0.03***
# * ***min_samples_leaf: 0.01***
# * ***max_features: Logaritmo (log2)***

# %% [markdown]
# Continuando con el asunto, se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Árbol de Decisión*** sobre el conjunto de datos. Para dicho modelo se tomara en cuenta los ***hiperparametros*** mencionados anteriormente. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. Para dibujar las curvas ***ROC***, se utiliza la función ***draw_rocs***. Por otro lado, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
idx = np.array(dtcallp).argsort()[-1] #Indice del mejor modelo
bestmodel = dtcmods[idx]

draw_rocs(bestmodel, df, 10)

# %% [markdown]
# ###***C. Máquinas de Vectores de Soporte (SVM)***

# %% [markdown]
# Se procedera a realizar el ajuste de hiperparametros para ***Máquinas de Vectores de Soporte (SVM)*** con el conjunto de datos dado. Con respecto a dicho ajuste, nos enfocaremos en ***2 hiperparametros*** principalmente, los cuales son ***C y Kernel***. Estos seran ajustados, ya que son considerados los más importantes. Se tratara de buscar la combinación de estos ***hiperparametros*** que maximize la performance de clasficación. Se aplicara ***cross-validation estratificado con K=10*** para el muestreo. La evaluación de cada combinación de ***hiperparametros*** se realizá con la función ***test_model_alt***. Llegados a este punto, se procedera a describir a los ***hiperparametros***:
#
# * ***C: Parámetro de regularización. Debe ser estrictamente positiva. El parámetro C se usa para manipular el margen. Si C es un valor grande, el margen es duro. Si C es pequeño, el margen es suave.***
#
# * ***Kernel: Especifica el tipo de núcleo que se utilizará en el algoritmo. Entre los posibles valores, se cuenta con Lineal (linear), Polinomial (poly), Radial Basis Function (rbf) y Sigmoidal (sigmoid).***

# %% [markdown]
# En el siguiente codigo, se define la función ***test_model_alt***. Esta función posee el mismo objetivo de la función ***test_model***, con la diferencia que esta no evalua la metrica ***Área bajo la Curva ROC (AUC)***. Esto se realiza así, puesto que determinar ***AUC*** utilizando el clasificador ***SVM*** representa un costo computacional muy alto. Por ello, se opto por omitir dicha metrica en este caso.

# %%
def test_model_alt(model, df, nfols): #Implementación de función alternativa para probar modelo con metricas
  X = df.iloc[:,:-1].values #Caracteristicas
  Y = df.iloc[:,-1].values #Columna objetivo
  skf = StratifiedKFold(n_splits=nfols)
  acuracym = 0 #Exactitud
  precisionm = 0 #Precisión
  recallm = 0 #Recall
  f1m = 0 #F1
  for train_index, test_index in skf.split(X, Y): #Cross-validation estratificado con k folds
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]
    model.fit(X_train, Y_train)
    predicciones = model.predict(X_test)
    acuracym += accuracy_score(Y_test, predicciones)
    precision, recall, f1, support = precision_recall_fscore_support(Y_test, predicciones, average='binary', zero_division=0)
    precisionm += precision
    recallm += recall
    f1m += f1
  return acuracym/nfols, precisionm/nfols, recallm/nfols, f1m/nfols

# %% [markdown]
# En el siguiente codigo, respecto a la busqueda de los mejores hiperparametros, no se estan evaluando todas las posibilidades. En este caso, lo que se propone es primero realizar una búsqueda general rápida, con el objetivo de ubicar, aproximadamente, el rango en el que se podría encontrar el ***hiperparametro*** óptimo. Una vez ubicado dicho rango, proceder con una búsqueda exhaustiva. Además, se almacena el ***promedio de las metricas*** obtenidas, por cada combinación de ***hiperparametros*** evaluada, en un arreglo. Con dicho promedio, se logra considerar la optimización de todas las metricas en la busqueda de los ***hiperparametros***.

# %%
from sklearn.svm import SVC

#Hiperparametros:
cs = [0.1, 1, 10, 100]
kernels = ['linear', 'poly', 'rbf', 'sigmoid']

svmallp = [] #Arreglo para guardar el promedio de todas las metricas
svmmods = [] #Arreglo para guardar los modelos ajustados

for c in cs:
  for k in kernels:
    svm = SVC(C=c, kernel=k)
    acc, pre, rec, f1 = test_model_alt(svm, df, 10)
    svmallp.append((acc+pre+rec+f1)/4)
    svmmods.append(svm)

# %% [markdown]
# Con la evaluación ***test_model_alt***, se consideran una serie de metricas, las cuales son promediadas y almacenadas durante la busqueda. En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(svmallp).argsort()[-1] #Indice del mejor modelo
bestmodel = svmmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", svmallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("Kernel: ", bestmodel.get_params()['kernel'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9725966070071771
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  100
# Kernel:  rbf

# %% [markdown]
# De acuerdo a lo obtenido anteriormente, con respecto a ***C (parametro de regularización)***, se logra identificar que el mejor valor para dicho ***hiperparametro*** es cercano a ***100***. En ese sentido, se reducira el rango a **[50, 150]**. Ahora bien, con respecto a ***Kernel***, el mejor valor es ***Radial Basis Function (rbf)***. Por lo tanto, debido a cuestiones de costo computacional, solo se tomara en cuenta ***rbf*** para la siguiente busqeuda. Teniendo en cuento estos rangos, se procedera a realizar una busqueda exhaustiva. Cabe mencionar que se almacenan las metricas obtenidas y el promedio de dichas metricas, por cada combinación de ***hiperparametros*** evaluada, en arreglos.

# %%
#Hiperparametros:
cs = [i for i in range(50, 150, 5)]
kernels = ['rbf']

svmacc = [] #Arreglo para guardar exactitudes
svmpre = [] #Arreglo para guardar precisiones
svmrec = [] #Arreglo para guardar recalls
svmf1 = [] #Arreglo para guardar F1s
svmallp = [] #Arreglo para guardar el promedio de todas las metricas
svmmods = [] #Arreglo para guardar los modelos ajustados

for c in cs: #Busqueda de hiperparametros
  for k in kernels:
    svm = SVC(C=c, kernel=k)
    acc, pre, rec, f1 = test_model_alt(svm, df, 10)
    svmacc.append(acc)
    svmpre.append(pre)
    svmrec.append(rec)
    svmf1.append(f1)
    svmallp.append((acc+pre+rec+f1)/4)
    svmmods.append(svm)

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
idx = np.array(svmallp).argsort()[-1] #Indice del mejor modelo
bestmodel = svmmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", svmallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("Kernel: ", bestmodel.get_params()['kernel'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9730853132902906
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  135
# Kernel:  rbf

# %% [markdown]
# Ahora bien, considerando el promedio de todas las metricas evaluadas, se logra definir los ***hiperparametros*** señalados anteriormente como los mejores. No obstante, ello puede cambiar si se analiza desde la perspectiva de cada metrica. Por lo tanto, se procedera a indicar el maximo valor obtenido de cada metrica, durante la busqueda, y los ***hiperparametros*** que permiten alcanzar dicho valor.

# %% [markdown]
# ####***C.1. Mejores hiperparametros según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Exactitud (Accuracy)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(svmacc).argsort()[-1] #Indice del mejor modelo
bestmodel = svmmods[idx]
print("Mejor Exactitud (Accuracy) obtenida en la busqueda: ", svmacc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("Kernel: ", bestmodel.get_params()['kernel'])
# Out:
# Mejor Exactitud (Accuracy) obtenida en la busqueda:  0.9729166666666667
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  135
# Kernel:  rbf

# %% [markdown]
# ####***C.2. Mejores hiperparametros según metrica de Precisión (precision)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Precisión (precision)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(svmpre).argsort()[-1] #Indice del mejor modelo
bestmodel = svmmods[idx]
print("Mejor Precisión (precision) obtenida en la busqueda: ", svmpre[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("Kernel: ", bestmodel.get_params()['kernel'])
# Out:
# Mejor Precisión (precision) obtenida en la busqueda:  0.966597288841528
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  135
# Kernel:  rbf

# %% [markdown]
# ####***C.3. Mejores hiperparametros según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***Recall*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(svmrec).argsort()[-1] #Indice del mejor modelo
bestmodel = svmmods[idx]
print("Mejor Recall obtenido en la busqueda: ", svmrec[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("Kernel: ", bestmodel.get_params()['kernel'])
# Out:
# Mejor Recall obtenido en la busqueda:  0.979722222222222
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  145
# Kernel:  rbf

# %% [markdown]
# ####***C.4. Mejores hiperparametros según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***F1*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(svmf1).argsort()[-1] #Indice del mejor modelo
bestmodel = svmmods[idx]
print("Mejor F1 obtenido en la busqueda: ", svmf1[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("Kernel: ", bestmodel.get_params()['kernel'])
# Out:
# Mejor F1 obtenido en la busqueda:  0.9731050754307453
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  135
# Kernel:  rbf

# %% [markdown]
# ####***C.5. Comparación y Síntesis***

# %% [markdown]
# En esta parte, se procedera a realizar la síntesis o resumen de los resultados obtenidos. Se empleara una comparación entre los mismos, con el objetivo de formular conclusiones apropiadas. La evaluación se desarrolla en base a distintas metricas. Entre ellas, cabe mencionar ***Exactitud, Precisión, Recall y F1***. En este caso, ***Area bajo la Curva (AUC)*** no es considerada como metrica de evaluación en la busqueda de ***hiperparametros***, debido a cuestiones basadas en recursos computacionales. Por otra parte, tambien se usa el ***Promedio de métricas***, el cual constituye el promedio de los valores de todas las metricas utilizadas. Dicho promedio fue planteado con el objetivo de considerar la maximización de todas las metricas en la busqueda de los mejores ***hiperparametros***. En la siguiente tabla, se presentan los ***hiperparametros*** que maximizan los valores de cada metrica. En ese sentido, ello permite identificar los mejores ***hiperparametros*** en base a que medida se desee optimizar.
#
# ![Tabla de resumen hiperparametros](https://i.ibb.co/kgNGsch/tabsvmhip.png)
#
# Respecto a los resultados obtenidos en la tabla anterior, es factible mencionar que el mejor valor para el ***hiperparametro Kernel*** es ***Radial Basis Function (RBF)***. Se concluye lo anterior, ya que para todas las metricas evaluadas, ***RBF*** es el valor que mejor funciona. Además, con respecto al valor del ***hiperparametro C (parametro de regularización)***, este se repite y coincide para ***4 metricas*** en la tabla, las cuales son ***F1, Exactitud, Precisión*** y ***Promedio de metricas***. Es posible argumentar que ***F1*** sirve como punto de equilibrio y engloba a ***Precisión*** y ***Recall***. Por lo tanto, se concluye que los ***hiperparametros*** que logran maximizar las metricas de forma conjunta y funcionan mejor con los datos son:
#
# * ***C (parametro de regularización): 135***
# * ***Kernel: Radial Basis Function (RBF)***

# %% [markdown]
# Continuando con el asunto, se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Máquinas de Vectores de Soporte (SVM)*** sobre el conjunto de datos. Para dicho modelo se tomara en cuenta los ***hiperparametros*** mencionados anteriormente. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. Para dibujar las curvas ***ROC***, se utiliza la función ***draw_rocs***. Por otro lado, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

bestmodel = SVC(C=135, kernel='rbf', probability=True) #El mejor modelo con los parametros encontrados
draw_rocs(bestmodel, df, 10)

# %% [markdown]
# ###***D. Random Forest***

# %% [markdown]
# Se procedera a realizar el ajuste de hiperparametros para ***Random Forest*** con el conjunto de datos dado. Con respecto a dicho ajuste, nos enfocaremos en ***4 hiperparametros*** principalmente, los cuales son ***Numero de estimadores (n_estimators), Profundidad maxima (max_depth), max_features y bootstrap***. Estos seran ajustados, ya que son considerados los más importantes. Se tratara de buscar la combinación de estos ***hiperparametros*** que maximize la performance de clasficación. Se aplicara ***cross-validation estratificado con K=10*** para el muestreo. La evaluación de cada combinación de ***hiperparametros*** se realizá con la función ***test_model***. Llegados a este punto, se procedera a describir a los ***hiperparametros***:
#
# * ***Numero de estimadores (n_estimators): El número de árboles en el bosque.***
#
# * ***Profundidad maxima (max_depth): Número máximo de niveles en cada árbol de decisión.***
#
# * ***max_features: Número máximo de características consideradas para dividir un nodo. Entre los posibles valores a considerar, tenemos Automatico (auto), Raíz (sqrt) y Logaritmo (log2).***
#
# * ***bootstrap: Si las muestras de bootstrap se usan al construir árboles. Este hiperparametro puede tomar el valor de Verdadero (True) o Falso (False). Si es falso, todo el conjunto de datos se usa para construir cada árbol.***

# %% [markdown]
# En el siguiente codigo, respecto a la busqueda de los mejores hiperparametros, no se estan evaluando todas las posibilidades. En este caso, lo que se propone es primero realizar una búsqueda general rápida, con el objetivo de ubicar, aproximadamente, el rango en el que se podría encontrar el ***hiperparametro*** óptimo. Una vez ubicado dicho rango, proceder con una búsqueda exhaustiva. Además, se almacena el ***promedio de las metricas*** obtenidas, por cada combinación de ***hiperparametros*** evaluada, en un arreglo. Con dicho promedio, se logra considerar la optimización de todas las metricas en la busqueda de los ***hiperparametros***.

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

#Hiperparametros:
nestims = [10, 50, 100, 200]
mdepts = [5, 10, 30, 50, 100]
mfeats = ['auto', 'sqrt', 'log2']
boots = [True, False]

rfcallp = [] #Arreglo para guardar el promedio de todas las metricas
rfcmods = [] #Arreglo para guardar los modelos ajustados

for ne in nestims: #Busqueda de hiperparametros
  for md in mdepts:
    for mf in mfeats:
      for b in boots:
        rfc = RFC(n_estimators=ne, max_depth=md, max_features=mf, bootstrap=b)
        acc, pre, rec, f1, auc = test_model(rfc, df, 10)
        rfcallp.append((acc+pre+rec+f1+auc)/5)
        rfcmods.append(rfc)

# %% [markdown]
# Con la evaluación ***test_model***, se consideran una serie de metricas, las cuales son promediadas y almacenadas durante la busqueda. En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(rfcallp).argsort()[-1] #Indice del mejor modelo
bestmodel = rfcmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", rfcallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de estimadores (n_estimators): ", bestmodel.get_params()['n_estimators'])
print("Profundidad maxima (max_depth): ", bestmodel.get_params()['max_depth'])
print("max_features: ", bestmodel.get_params()['max_features'])
print("bootstrap: ", bestmodel.get_params()['bootstrap'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9782349930672185
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de estimadores (n_estimators):  200
# Profundidad maxima (max_depth):  10
# max_features:  sqrt
# bootstrap:  True

# %% [markdown]
# De acuerdo a lo obtenido anteriormente, con respecto al ***Numero de estimadores (n_estimators)***, se logra identificar que el mejor valor para dicho ***hiperparametro*** es cercano a ***200***. En ese sentido, se reducirá el rango a **[175, 250]**. Asimismo, el valor optimo para ***Profundidad maxima (max_depth)*** se aproxima a ***10***, por lo que se reducirá el rango a **[7,20]**. Continuando con el asunto, se procedera a realizar una busqueda exhaustiva. Cabe mencionar que se almacenan las metricas obtenidas y el promedio de dichas metricas, por cada combinación de ***hiperparametros*** evaluada, en arreglos.

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

#Hiperparametros:
nestims = [i for i in range(175, 251, 25)]
mdepts = [i for i in range(7, 20, 3)]
mfeats = ['auto', 'sqrt', 'log2']
boots = [True, False]

rfcacc = [] #Arreglo para guardar exactitudes
rfcpre = [] #Arreglo para guardar precisiones
rfcrec = [] #Arreglo para guardar recalls
rfcf1 = [] #Arreglo para guardar F1s
rfcauc = [] #Arreglo para guardar AUCs
rfcallp = [] #Arreglo para guardar el promedio de todas las metricas
rfcmods = [] #Arreglo para guardar los modelos ajustados

for ne in nestims: #Busqueda de hiperparametros
  for md in mdepts:
    for mf in mfeats:
      for b in boots:
        rfc = RFC(n_estimators=ne, max_depth=md, max_features=mf, bootstrap=b)
        acc, pre, rec, f1, auc = test_model(rfc, df, 10)
        rfcacc.append(acc)
        rfcpre.append(pre)
        rfcrec.append(rec)
        rfcf1.append(f1)
        rfcauc.append(auc)
        rfcallp.append((acc+pre+rec+f1+auc)/5)
        rfcmods.append(rfc)

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(rfcallp).argsort()[-1] #Indice del mejor modelo
bestmodel = rfcmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", rfcallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de estimadores (n_estimators): ", bestmodel.get_params()['n_estimators'])
print("Profundidad maxima (max_depth): ", bestmodel.get_params()['max_depth'])
print("max_features: ", bestmodel.get_params()['max_features'])
print("bootstrap: ", bestmodel.get_params()['bootstrap'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9780122533581356
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de estimadores (n_estimators):  200
# Profundidad maxima (max_depth):  10
# max_features:  auto
# bootstrap:  True

# %% [markdown]
# Ahora bien, considerando el promedio de todas las metricas evaluadas, se logra definir los ***hiperparametros*** señalados anteriormente como los mejores. No obstante, ello puede cambiar si se analiza desde la perspectiva de cada metrica. Por lo tanto, se procedera a indicar el maximo valor obtenido de cada metrica, durante la busqueda, y los ***hiperparametros*** que permiten alcanzar dicho valor.

# %% [markdown]
# ####***D.1. Mejores hiperparametros según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Exactitud (Accuracy)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(rfcacc).argsort()[-1] #Indice del mejor modelo
bestmodel = rfcmods[idx]
print("Mejor Exactitud (Accuracy) obtenida en la busqueda: ", rfcacc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de estimadores (n_estimators): ", bestmodel.get_params()['n_estimators'])
print("Profundidad maxima (max_depth): ", bestmodel.get_params()['max_depth'])
print("max_features: ", bestmodel.get_params()['max_features'])
print("bootstrap: ", bestmodel.get_params()['bootstrap'])
# Out:
# Mejor Exactitud (Accuracy) obtenida en la busqueda:  0.9733333333333334
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de estimadores (n_estimators):  200
# Profundidad maxima (max_depth):  10
# max_features:  auto
# bootstrap:  True

# %% [markdown]
# ####***D.2. Mejores hiperparametros según metrica de Precisión (precision)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Precisión (precision)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(rfcpre).argsort()[-1] #Indice del mejor modelo
bestmodel = rfcmods[idx]
print("Mejor Precisión (precision) obtenida en la busqueda: ", rfcpre[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de estimadores (n_estimators): ", bestmodel.get_params()['n_estimators'])
print("Profundidad maxima (max_depth): ", bestmodel.get_params()['max_depth'])
print("max_features: ", bestmodel.get_params()['max_features'])
print("bootstrap: ", bestmodel.get_params()['bootstrap'])
# Out:
# Mejor Precisión (precision) obtenida en la busqueda:  0.9681069546131555
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de estimadores (n_estimators):  250
# Profundidad maxima (max_depth):  10
# max_features:  auto
# bootstrap:  False

# %% [markdown]
# ####***D.3. Mejores hiperparametros según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***Recall*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(rfcrec).argsort()[-1] #Indice del mejor modelo
bestmodel = rfcmods[idx]
print("Mejor Recall obtenido en la busqueda: ", rfcrec[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de estimadores (n_estimators): ", bestmodel.get_params()['n_estimators'])
print("Profundidad maxima (max_depth): ", bestmodel.get_params()['max_depth'])
print("max_features: ", bestmodel.get_params()['max_features'])
print("bootstrap: ", bestmodel.get_params()['bootstrap'])
# Out:
# Mejor Recall obtenido en la busqueda:  0.9805555555555557
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de estimadores (n_estimators):  200
# Profundidad maxima (max_depth):  7
# max_features:  auto
# bootstrap:  True

# %% [markdown]
# ####***D.4. Mejores hiperparametros según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***F1*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(rfcf1).argsort()[-1] #Indice del mejor modelo
bestmodel = rfcmods[idx]
print("Mejor F1 obtenido en la busqueda: ", rfcf1[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de estimadores (n_estimators): ", bestmodel.get_params()['n_estimators'])
print("Profundidad maxima (max_depth): ", bestmodel.get_params()['max_depth'])
print("max_features: ", bestmodel.get_params()['max_features'])
print("bootstrap: ", bestmodel.get_params()['bootstrap'])
# Out:
# Mejor F1 obtenido en la busqueda:  0.9735168608125914
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de estimadores (n_estimators):  200
# Profundidad maxima (max_depth):  10
# max_features:  auto
# bootstrap:  True

# %% [markdown]
# ####***D.5. Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Área bajo la curva ROC (AUC)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(rfcauc).argsort()[-1] #Indice del mejor modelo
bestmodel = rfcmods[idx]
print("Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda: ", rfcauc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("Numero de estimadores (n_estimators): ", bestmodel.get_params()['n_estimators'])
print("Profundidad maxima (max_depth): ", bestmodel.get_params()['max_depth'])
print("max_features: ", bestmodel.get_params()['max_features'])
print("bootstrap: ", bestmodel.get_params()['bootstrap'])
# Out:
# Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda:  0.9961180555555555
#
# Mejores Hiperparametros obtenidos en la busqueda:
# Numero de estimadores (n_estimators):  175
# Profundidad maxima (max_depth):  10
# max_features:  sqrt
# bootstrap:  True

# %% [markdown]
# ####***D.6. Comparación y Síntesis***

# %% [markdown]
# En esta parte, se procedera a realizar la síntesis o resumen de los resultados obtenidos. Se empleara una comparación entre los mismos, con el objetivo de formular conclusiones apropiadas. La evaluación se desarrolla en base a distintas metricas. Entre ellas, cabe mencionar ***Exactitud, Precisión, Recall, F1 y Área bajo la curva ROC (AUC)***. Asimismo, tambien se usa el ***Promedio de métricas***, el cual constituye el promedio de los valores de todas las metricas mencionadas. Dicho promedio fue planteado con el objetivo de considerar la maximización de todas las metricas en la busqueda de los mejores hiperparametros. En la siguiente tabla, se presentan los ***hiperparametros*** que maximizan los valores de cada metrica. En ese sentido, ello permite identificar los mejores ***hiperparametros*** en base a que medida se desee optimizar.
#
# ![Tabla de resumen hiperparametros](https://i.ibb.co/2WP5W9Z/tablarfchip.png)
#
# Respecto a los resultados obtenidos en la tabla anterior, es factible mencionar que el mejor valor para el ***hiperparametro Numero de estimadores (n_estimators)*** es ***200***, ya que este logra ser mejor para la mayoria de métricas. Asimismo, con respecto al valor optimo de ***Profundidad maxima (max_depth)***, en la mayoria de casos este es ***10***. De la misma manera, para los ***hiperparametros max features*** y ***bootstrap***, se logra determinar ***auto*** y ***TRUE*** como los mejores valores, ya que funcionan para la mayoria de métricas. Por lo tanto, se concluye que los ***hiperparametros*** que logran maximizar las metricas de forma conjunta y funcionan mejor con los datos son:
#
# * ***Numero de estimadores (n_estimators):  200***
# * ***Profundidad maxima (max_depth):  10***
# * ***max_features:  auto***
# * ***bootstrap:  True***

# %% [markdown]
# Continuando con el asunto, se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Random Forest*** sobre el conjunto de datos. Para dicho modelo se tomara en cuenta los ***hiperparametros*** mencionados anteriormente. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. Para dibujar las curvas ***ROC***, se utiliza la función ***draw_rocs***. Por otro lado, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve

idx = np.array(rfcallp).argsort()[-1] #Indice del mejor modelo
bestmodel = rfcmods[idx]

draw_rocs(bestmodel, df, 10)

# %% [markdown]
# ###***E. Regresión Logistica (Logistic Regression)***

# %% [markdown]
# Se procedera a realizar el ajuste de hiperparametros para ***Regresión Logistica (Logistic Regression)*** con el conjunto de datos dado. Con respecto a dicho ajuste, nos enfocaremos en ***3 hiperparametros*** principalmente, los cuales son ***C (parametro de regularización), class_weight y Solucionador (solver)***. Estos seran ajustados, ya que son considerados los más importantes. Se tratara de buscar la combinación de estos ***hiperparametros*** que maximize la performance de clasficación. Se aplicara ***cross-validation estratificado con K=10*** para el muestreo. La evaluación de cada combinación de ***hiperparametros*** se realizá con la función ***test_model***. Llegados a este punto, se procedera a describir a los ***hiperparametros***:
#
# * ***C: Parametro de regularización inverso de la fuerza de regularización; debe ser un valor positivo. Al igual que en las máquinas de vectores de soporte (SVM), los valores más pequeños especifican una regularización más fuerte.***
#
# * ***class_weight: Pesos asociados con clases. Si no se especifica, se supone que todas las clases tienen un peso uno. Entre los posibles valores que se pueden tomar, tenemos Ninguno (none) o Balanceado (balanced).***
#
# * ***Solucionador (solver): Indica el algoritmo a utilizar en el problema de optimización. El algoritmo puede ser newton-cg, lbfgs, liblinear, sag o saga.***

# %% [markdown]
# En el siguiente codigo, respecto a la busqueda de los mejores hiperparametros, no se estan evaluando todas las posibilidades. En este caso, lo que se propone es primero realizar una búsqueda general rápida, con el objetivo de ubicar, aproximadamente, el rango en el que se podría encontrar el ***hiperparametro*** óptimo. Una vez ubicado dicho rango, proceder con una búsqueda exhaustiva. Además, se almacena el ***F1*** obtenido, por cada combinación de ***hiperparametros*** evaluada, en un arreglo.

# %%
from sklearn.linear_model import LogisticRegression as LR

#Hiperparametros:
cs = [0.1, 1, 10, 50, 100, 200, 300, 400, 500, 600, 700, 800, 1000, 2000, 3000]
cweigts = [None, 'balanced']
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']

lrf1 = [] #Arreglo para guardar F1s
lrmods = [] #Arreglo para guardar los modelos ajustados

for c in cs: #Busqueda de hiperparametros
  for w in cweigts:
    for s in solvers:
      lr = LR(C=c, class_weight=w, solver=s)
      acc, pre, rec, f1, auc = test_model(lr, df, 10)
      lrf1.append(f1)
      lrmods.append(lr)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ...

# %% [markdown]
# Con la evaluación ***test_model***, se consideran una serie de metricas, las cuales son promediadas y almacenadas durante la busqueda. En el siguiente codigo, se indica el máximo ***F1*** obtenido en la busqueda. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
import numpy as np

idx = np.array(lrf1).argsort()[-1] #Indice del mejor modelo
bestmodel = lrmods[idx]
print("Mejor F1 obtenido en la busqueda: ", lrf1[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("class_weight: ", bestmodel.get_params()['class_weight'])
print("Solucionador (solver): ", bestmodel.get_params()['solver'])
# Out:
# Mejor F1 obtenido en la busqueda:  0.9041600943774158
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  200
# class_weight:  None
# Solucionador (solver):  newton-cg

# %% [markdown]
# De acuerdo a lo obtenido anteriormente, con respecto a ***C (parametro de regularización)***, se logra identificar que el mejor valor para dicho ***hiperparametro*** es cercano a ***200***. En ese sentido, se reducirá el rango a **[100, 300]**, y se procederá a realizar una busqueda exhaustiva. Cabe mencionar que se almacenan las metricas obtenidas y el promedio de dichas metricas, por cada combinación de ***hiperparametros*** evaluada, en arreglos.

# %%
from sklearn.linear_model import LogisticRegression as LR

#Hiperparametros:
cs = [i for i in range(100, 300, 5)]
cweigts = [None, 'balanced']
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']

lracc = [] #Arreglo para guardar exactitudes
lrpre = [] #Arreglo para guardar precisiones
lrrec = [] #Arreglo para guardar recalls
lrf1 = [] #Arreglo para guardar F1s
lrauc = [] #Arreglo para guardar AUCs
lrallp = [] #Arreglo para guardar el promedio de todas las metricas
lrmods = [] #Arreglo para guardar los modelos ajustados

for c in cs: #Busqueda de hiperparametros
  for w in cweigts:
    for s in solvers:
      lr = LR(C=c, class_weight=w, solver=s)
      acc, pre, rec, f1, auc = test_model(lr, df, 10)
      lracc.append(acc)
      lrpre.append(pre)
      lrrec.append(rec)
      lrf1.append(f1)
      lrauc.append(auc)
      lrallp.append((acc+pre+rec+f1+auc)/5)
      lrmods.append(lr)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ...

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(lrallp).argsort()[-1] #Indice del mejor modelo
bestmodel = lrmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", lrallp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("class_weight: ", bestmodel.get_params()['class_weight'])
print("Solucionador (solver): ", bestmodel.get_params()['solver'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.9167493423939973
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  280
# class_weight:  balanced
# Solucionador (solver):  sag

# %% [markdown]
# Ahora bien, considerando el promedio de todas las metricas evaluadas, se logra definir los ***hiperparametros*** señalados anteriormente como los mejores. No obstante, ello puede cambiar si se analiza desde la perspectiva de cada metrica. Por lo tanto, se procedera a indicar el maximo valor obtenido de cada metrica, durante la busqueda, y los ***hiperparametros*** que permiten alcanzar dicho valor.

# %% [markdown]
# ####***E.1. Mejores hiperparametros según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Exactitud (Accuracy)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(lracc).argsort()[-1] #Indice del mejor modelo
bestmodel = lrmods[idx]
print("Mejor Exactitud (Accuracy) obtenida en la busqueda: ", lracc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("class_weight: ", bestmodel.get_params()['class_weight'])
print("Solucionador (solver): ", bestmodel.get_params()['solver'])
# Out:
# Mejor Exactitud (Accuracy) obtenida en la busqueda:  0.9090972222222223
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  245
# class_weight:  balanced
# Solucionador (solver):  liblinear

# %% [markdown]
# ####***E.2. Mejores hiperparametros según metrica de Precisión (precision)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Precisión (precision)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(lrpre).argsort()[-1] #Indice del mejor modelo
bestmodel = lrmods[idx]
print("Mejor Precisión (precision) obtenida en la busqueda: ", lrpre[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("class_weight: ", bestmodel.get_params()['class_weight'])
print("Solucionador (solver): ", bestmodel.get_params()['solver'])
# Out:
# Mejor Precisión (precision) obtenida en la busqueda:  0.9555743683641758
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  245
# class_weight:  balanced
# Solucionador (solver):  liblinear

# %% [markdown]
# ####***E.3. Mejores hiperparametros según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***Recall*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(lrrec).argsort()[-1] #Indice del mejor modelo
bestmodel = lrmods[idx]
print("Mejor Recall obtenido en la busqueda: ", lrrec[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("class_weight: ", bestmodel.get_params()['class_weight'])
print("Solucionador (solver): ", bestmodel.get_params()['solver'])
# Out:
# Mejor Recall obtenido en la busqueda:  0.8581944444444444
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  245
# class_weight:  balanced
# Solucionador (solver):  liblinear

# %% [markdown]
# ####***E.4. Mejores hiperparametros según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***F1*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(lrf1).argsort()[-1] #Indice del mejor modelo
bestmodel = lrmods[idx]
print("Mejor F1 obtenido en la busqueda: ", lrf1[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("class_weight: ", bestmodel.get_params()['class_weight'])
print("Solucionador (solver): ", bestmodel.get_params()['solver'])
# Out:
# Mejor F1 obtenido en la busqueda:  0.9041600943774158
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  245
# class_weight:  balanced
# Solucionador (solver):  liblinear

# %% [markdown]
# ####***E.5. Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Área bajo la curva ROC (AUC)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(lrauc).argsort()[-1] #Indice del mejor modelo
bestmodel = lrmods[idx]
print("Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda: ", lrauc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("C (parametro de regularización): ", bestmodel.get_params()['C'])
print("class_weight: ", bestmodel.get_params()['class_weight'])
print("Solucionador (solver): ", bestmodel.get_params()['solver'])
# Out:
# Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda:  0.9567342785493826
#
# Mejores Hiperparametros obtenidos en la busqueda:
# C (parametro de regularización):  100
# class_weight:  balanced
# Solucionador (solver):  saga

# %% [markdown]
# ####***E.6. Comparación y Síntesis***

# %% [markdown]
# En esta parte, se procedera a realizar la síntesis o resumen de los resultados obtenidos. Se empleara una comparación entre los mismos, con el objetivo de formular conclusiones apropiadas. La evaluación se desarrolla en base a distintas metricas. Entre ellas, cabe mencionar ***Exactitud, Precisión, Recall, F1 y Área bajo la curva ROC (AUC)***. Asimismo, tambien se usa el ***Promedio de métricas***, el cual constituye el promedio de los valores de todas las metricas mencionadas. Dicho promedio fue planteado con el objetivo de considerar la maximización de todas las metricas en la busqueda de los mejores hiperparametros. En la siguiente tabla, se presentan los ***hiperparametros*** que maximizan los valores de cada metrica. En ese sentido, ello permite identificar los mejores ***hiperparametros*** en base a que medida se desee optimizar.
#
# ![Tabla de resumen hiperparametros](https://i.ibb.co/5nsJp6C/tablalrhip.png)
#
# Respecto a los resultados obtenidos en la tabla anterior, es factible mencionar que el mejor valor para el ***hiperparametro C (parametro de regularización)*** es ***245***, ya que este logra ser mejor para la mayoria de métricas. Asimismo, con respecto al valor optimo de ***Solucionador (solver)***, en la mayoria de casos este es ***liblinear***. De la misma manera, para el ***hiperparametro class_weight***, se logra determinar ***Balanceado*** como el mejor valor, ya que optimiza todas las métricas. Por lo tanto, se concluye que los ***hiperparametros*** que logran maximizar las metricas de forma conjunta y funcionan mejor con los datos son:
#
# * ***C (parametro de regularización):  245***
# * ***class_weight:  Balanceado (balanced)***
# * ***Solucionador (solver):  liblinear***

# %% [markdown]
# Continuando con el asunto, se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Regresión Logistica (Logistic Regression)*** sobre el conjunto de datos. Para dicho modelo se tomara en cuenta los ***hiperparametros*** mencionados anteriormente. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. Para dibujar las curvas ***ROC***, se utiliza la función ***draw_rocs***. Por otro lado, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
idx = np.array(lrf1).argsort()[-1] #Indice del mejor modelo
bestmodel = lrmods[idx]

draw_rocs(bestmodel, df, 10)

# %% [markdown]
# ###***F. Redes Bayesianas Multinomiales (Multinomial Naive Bayes)***

# %% [markdown]
# Se procedera a realizar el ajuste de hiperparametros para ***Redes Bayesianas Multinomiales (Multinomial Naive Bayes)*** con el conjunto de datos dado. Con respecto a dicho ajuste, nos enfocaremos en ***2 hiperparametros*** principalmente, los cuales son ***alpha y fit_prior***. Estos seran ajustados, ya que son considerados los más importantes. Se tratara de buscar la combinación de estos ***hiperparametros*** que maximize la performance de clasficación. Se aplicara ***cross-validation estratificado con K=10*** para el muestreo. La evaluación de cada combinación de ***hiperparametros*** se realizá con la función ***test_model***. Llegados a este punto, se procedera a describir a los ***hiperparametros***:
#
# * ***alpha: Parámetro de suavizado aditivo (Laplace / Lidstone) (0 para no suavizado).***
#
# * ***fit_prior: Indica si se aprenden las probabilidades prioritarias de las clases o no. Este hiperparametro puede ser Verdadero (True) o Falso (False). Si es falso, se usará prioridades uniformes.***

# %% [markdown]
# Para poder evaluar el conjunto de datos con ***Multinomial Naive Bayes***, todos los valores de las caracteristicas deben ser positivos. En otras palabras, los datos de entrada no pueden ser negativos. En ese sentido, se aplicara una ***normalización*** sobre el conjunto de datos, con el objetivo de poder hacer uso del algoritmo ***Redes Bayesianas Multinomiales***. Luego de aplicar la ***normalización***, se imprime una descripción del conjunto de datos. Esta descripción muestra que todos las columnas poseen un rango de **[0, 1]**.

# %%
dfn = df.copy()
names = df.columns.values
for i in range(len(names)): dfn[names[i]] = (df[names[i]] - df[names[i]].min())/ (df[names[i]].max()-df[names[i]].min())
dfn.describe()
# Out:
#            merchant      category        amount         fraud
# count  14400.000000  14400.000000  14400.000000  14400.000000
# mean       0.604765      0.673800      0.033933      0.500000
# std        0.246865      0.257841      0.076977      0.500017
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.367347      0.428571      0.003301      0.000000
# 50%        0.612245      0.857143      0.007083      0.500000
# 75%        0.795918      0.857143      0.038370      1.000000
# max        1.000000      1.000000      1.000000      1.000000

# %% [markdown]
# En el siguiente codigo, respecto a la busqueda de los mejores hiperparametros, no se estan evaluando todas las posibilidades. En este caso, lo que se propone es primero realizar una búsqueda general rápida, con el objetivo de ubicar, aproximadamente, el rango en el que se podría encontrar el ***hiperparametro*** óptimo. Una vez ubicado dicho rango, proceder con una búsqueda exhaustiva. Además, se almacena el ***promedio de las metricas*** obtenidas, por cada combinación de ***hiperparametros*** evaluada, en un arreglo. Con dicho promedio, se logra considerar la optimización de todas las metricas en la busqueda de los ***hiperparametros***.

# %%
from sklearn.naive_bayes import MultinomialNB

#Hiperparametros:
alphas = [0.001, 0.01, 0.1, 0.5, 1, 5, 10, 30, 50, 100]
fpriors = [True, False]

mnballp = [] #Arreglo para guardar el promedio de todas las metricas
mnbmods = [] #Arreglo para guardar los modelos ajustados

for a in alphas: #Busqueda de hiperparametros
  for f in fpriors:
    mnb = MultinomialNB(alpha=a, fit_prior=f)
    acc, pre, rec, f1, auc = test_model(mnb, dfn, 10)
    mnballp.append((acc+pre+rec+f1+auc)/5)
    mnbmods.append(mnb)

# %% [markdown]
# Con la evaluación ***test_model***, se consideran una serie de metricas, las cuales son promediadas y almacenadas durante la busqueda. En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(mnballp).argsort()[-1] #Indice del mejor modelo
bestmodel = mnbmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", mnballp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("alpha: ", bestmodel.get_params()['alpha'])
print("fit_prior: ", bestmodel.get_params()['fit_prior'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.8299828028883933
#
# Mejores Hiperparametros obtenidos en la busqueda:
# alpha:  0.001
# fit_prior:  True

# %% [markdown]
# De acuerdo a lo obtenido anteriormente, con respecto a ***alpha***, se logra identificar que el mejor valor para dicho ***hiperparametro*** es cercano a ***0.001***. En ese sentido, se reducirá el rango a **[0, 1]**, y se procedera a realizar una busqueda exhaustiva. Cabe mencionar que se almacenan las metricas obtenidas y el promedio de dichas metricas, por cada combinación de ***hiperparametros*** evaluada, en arreglos.

# %%
from sklearn.naive_bayes import MultinomialNB

#Hiperparametros:
alphas = list(np.linspace(0, 1, 1000))
fpriors = [True, False]

mnbacc = [] #Arreglo para guardar exactitudes
mnbpre = [] #Arreglo para guardar precisiones
mnbrec = [] #Arreglo para guardar recalls
mnbf1 = [] #Arreglo para guardar F1s
mnbauc = [] #Arreglo para guardar AUCs
mnballp = [] #Arreglo para guardar el promedio de todas las metricas
mnbmods = [] #Arreglo para guardar los modelos ajustados

for a in alphas: #Busqueda de hiperparametros
  for f in fpriors:
    mnb = MultinomialNB(alpha=a, fit_prior=f)
    acc, pre, rec, f1, auc = test_model(mnb, dfn, 10)
    mnbacc.append(acc)
    mnbpre.append(pre)
    mnbrec.append(rec)
    mnbf1.append(f1)
    mnbauc.append(auc)
    mnballp.append((acc+pre+rec+f1+auc)/5)
    mnbmods.append(mnb)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# ...

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***promedio de metricas*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho promedio.

# %%
import numpy as np

idx = np.array(mnballp).argsort()[-1] #Indice del mejor modelo
bestmodel = mnbmods[idx]
print("Mejor promedio de metricas obtenido en la busqueda: ", mnballp[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("alpha: ", bestmodel.get_params()['alpha'])
print("fit_prior: ", bestmodel.get_params()['fit_prior'])
# Out:
# Mejor promedio de metricas obtenido en la busqueda:  0.8299828800488871
#
# Mejores Hiperparametros obtenidos en la busqueda:
# alpha:  0.0
# fit_prior:  True

# %% [markdown]
# Ahora bien, considerando el promedio de todas las metricas evaluadas, se logra definir los ***hiperparametros*** señalados anteriormente como los mejores. No obstante, ello puede cambiar si se analiza desde la perspectiva de cada metrica. Por lo tanto, se procedera a indicar el maximo valor obtenido de cada metrica, durante la busqueda, y los ***hiperparametros*** que permiten alcanzar dicho valor.

# %% [markdown]
# ####***F.1. Mejores hiperparametros según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Exactitud (Accuracy)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(mnbacc).argsort()[-1] #Indice del mejor modelo
bestmodel = mnbmods[idx]
print("Mejor Exactitud (Accuracy) obtenida en la busqueda: ", mnbacc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("alpha: ", bestmodel.get_params()['alpha'])
print("fit_prior: ", bestmodel.get_params()['fit_prior'])
# Out:
# Mejor Exactitud (Accuracy) obtenida en la busqueda:  0.8240972222222223
#
# Mejores Hiperparametros obtenidos en la busqueda:
# alpha:  0.0
# fit_prior:  True

# %% [markdown]
# ####***F.2. Mejores hiperparametros según metrica de Precisión (precision)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Precisión (precision)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(mnbpre).argsort()[-1] #Indice del mejor modelo
bestmodel = mnbmods[idx]
print("Mejor Precisión (precision) obtenida en la busqueda: ", mnbpre[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("alpha: ", bestmodel.get_params()['alpha'])
print("fit_prior: ", bestmodel.get_params()['fit_prior'])
# Out:
# Mejor Precisión (precision) obtenida en la busqueda:  0.8352963855727185
#
# Mejores Hiperparametros obtenidos en la busqueda:
# alpha:  1.0
# fit_prior:  False

# %% [markdown]
# ####***F.3. Mejores hiperparametros según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***Recall*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(mnbrec).argsort()[-1] #Indice del mejor modelo
bestmodel = mnbmods[idx]
print("Mejor Recall obtenido en la busqueda: ", mnbrec[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("alpha: ", bestmodel.get_params()['alpha'])
print("fit_prior: ", bestmodel.get_params()['fit_prior'])
# Out:
# Mejor Recall obtenido en la busqueda:  0.8081944444444444
#
# Mejores Hiperparametros obtenidos en la busqueda:
# alpha:  0.0
# fit_prior:  True

# %% [markdown]
# ####***F.4. Mejores hiperparametros según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el máximo ***F1*** obtenido en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(mnbf1).argsort()[-1] #Indice del mejor modelo
bestmodel = mnbmods[idx]
print("Mejor F1 obtenido en la busqueda: ", mnbf1[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("alpha: ", bestmodel.get_params()['alpha'])
print("fit_prior: ", bestmodel.get_params()['fit_prior'])
# Out:
# Mejor F1 obtenido en la busqueda:  0.8211996967317038
#
# Mejores Hiperparametros obtenidos en la busqueda:
# alpha:  0.0
# fit_prior:  True

# %% [markdown]
# ####***F.5. Mejores hiperparametros según metrica de Área bajo la curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica la máxima ***Área bajo la curva ROC (AUC)*** obtenida en la busqueda anterior. Igualmente, se imprimen los ***hiperparametros*** con los que se logra alcanzar dicho valor.

# %%
idx = np.array(mnbauc).argsort()[-1] #Indice del mejor modelo
bestmodel = mnbmods[idx]
print("Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda: ", mnbauc[idx], end="\n\n")
print("Mejores Hiperparametros obtenidos en la busqueda:")
print("alpha: ", bestmodel.get_params()['alpha'])
print("fit_prior: ", bestmodel.get_params()['fit_prior'])
# Out:
# Mejor Área bajo la curva ROC (AUC) obtenida en la busqueda:  0.8611524884259258
#
# Mejores Hiperparametros obtenidos en la busqueda:
# alpha:  0.0
# fit_prior:  True

# %% [markdown]
# ####***F.6. Comparación y Síntesis***

# %% [markdown]
# En esta parte, se procedera a realizar la síntesis o resumen de los resultados obtenidos. Se empleara una comparación entre los mismos, con el objetivo de formular conclusiones apropiadas. La evaluación se desarrolla en base a distintas metricas. Entre ellas, cabe mencionar ***Exactitud, Precisión, Recall, F1 y Área bajo la curva ROC (AUC)***. Asimismo, tambien se usa el ***Promedio de métricas***, el cual constituye el promedio de los valores de todas las metricas mencionadas. Dicho promedio fue planteado con el objetivo de considerar la maximización de todas las metricas en la busqueda de los mejores hiperparametros. En la siguiente tabla, se presentan los ***hiperparametros*** que maximizan los valores de cada metrica. En ese sentido, ello permite identificar los mejores ***hiperparametros*** en base a que medida se desee optimizar.
#
# ![Tabla de resumen hiperparametros](https://i.ibb.co/N1yzFM6/tablamnbhip.png)
#
# Respecto a los resultados obtenidos en la tabla anterior, es factible mencionar que el mejor valor para el ***hiperparametro alpha*** es ***0***, ya que este logra ser mejor para la mayoria de métricas. De igual manera, con respecto al valor optimo de ***fit_prior***, en la mayoria de casos este es ***TRUE***. Por lo tanto, se concluye que los ***hiperparametros*** que logran maximizar las metricas de forma conjunta y funcionan mejor con los datos son:
#
# * ***alpha:  0***
# * ***fit_prior:  True***

# %% [markdown]
# Continuando con el asunto, se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Redes Bayesianas Multinomiales (Multinomial Naive Bayes)*** sobre el conjunto de datos. Para dicho modelo se tomara en cuenta los ***hiperparametros*** mencionados anteriormente. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. Para dibujar las curvas ***ROC***, se utiliza la función ***draw_rocs***. Por otro lado, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
idx = np.array(mnballp).argsort()[-1] #Indice del mejor modelo
bestmodel = mnbmods[idx]

draw_rocs(bestmodel, dfn, 10)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# ...

# %% [markdown]
# ##***2. Análisis del mejor clasificador con métricas de desempeño***

# %% [markdown]
# En esta sección, se evaluaran los ***mejores modelos*** producidos por cada algoritmo de aprendizaje supervisado analizado. En este caso, cada ***clasificador*** sera evaluado con el conjunto de datos. Cabe mencionar que los modelos de cada ***clasificador*** a comparar estarán configurados con los mejores ***hiperparametros*** respectivos encontrados para dicho ***clasificador***. Los clasificadores a comparar son ***K Vecinos más Cercanos (KNN)***, ***Árbol de Decisión***, ***Máquinas de Vectores de Soporte (SVM)***, ***Random Forest***, ***Regresión Logistica (Logistic Regression)*** y ***Redes Bayesianas Multinomiales (Multinomial Naive Bayes)***. Dado el ***mejor modelo*** de cada clasificador, se reportarán los valores de las siguientes metricas: ***Exactitud, Precisión, Recall, F1 y Área bajo la curva ROC (AUC)***. Dichas metricas seran comparadas, con el objetivo de determinar el ***mejor modelo*** para el conjunto de datos analizado. En adición a ello, tambien se realizará el grafico de las curvas ***Receiver Operating Characteristics (ROC)*** respectivas para cada caso.

# %% [markdown]
# En el siguiente codigo, se implementa la función ***test_model2***, la cual es una versión alternativa de la función ***test_model***. ***test_model2*** tambien retorna distintas metricas de evaluación, tales como ***exactitud, precisión, recall, F1 y Área bajo la curva ROC (AUC)***. No obstante, en el caso de ***precisión***, ***recall*** y ***f1***, ***test_model2*** permite obtener el valor de dichas metricas para ambas clases ***(fraude y no fraude)***.

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import roc_auc_score

def test_model2(model, df, nfols): #Implementación de función para probar modelo con metricas
  X = df.iloc[:,:-1].values #Caracteristicas
  Y = df.iloc[:,-1].values #Columna objetivo
  skf = StratifiedKFold(n_splits=nfols)
  acuracym = 0 #Exactitud
  precisionpm = 0 #Precisión
  recallpm = 0 #Recall
  f1pm = 0 #F1
  precisionnm = 0 #Precisión
  recallnm = 0 #Recall
  f1nm = 0 #F1
  aucm = 0 #Area bajo la curva ROC
  for train_index, test_index in skf.split(X, Y): #Cross-validation estratificado con k folds
    X_train, X_test = X[train_index], X[test_index]
    Y_train, Y_test = Y[train_index], Y[test_index]
    model.fit(X_train, Y_train)
    predicciones = model.predict(X_test)
    acuracym += accuracy_score(Y_test, predicciones)
    precisionp, recallp, f1p, support = precision_recall_fscore_support(Y_test, predicciones, pos_label=1, average='binary', zero_division=0)
    precisionn, recalln, f1n, support = precision_recall_fscore_support(Y_test, predicciones, pos_label=0, average='binary', zero_division=0)
    precisionpm += precisionp
    recallpm += recallp
    f1pm += f1p
    precisionnm += precisionn
    recallnm += recalln
    f1nm += f1n
    aucm += roc_auc_score(Y_test, model.predict_proba(X_test)[::,1])
  return acuracym/nfols, precisionpm/nfols, recallpm/nfols, f1pm/nfols, precisionnm/nfols, recallnm/nfols, f1nm/nfols, aucm/nfols

# %% [markdown]
# ###***A. Análisis del mejor modelo de K Vecinos más Cercanos (KNN)***

# %% [markdown]
# El ***mejor modelo*** encontrado para ***K Vecinos más Cercanos (KNN)*** se constituye de la siguiente configuración de ***hiperparametros***:
#
# * ***Numero de vecinos (n_neighbors): 15***
# * ***Pesos (weights): Uniform***
# * ***Algoritmo (algorithm): Brute***

# %% [markdown]
# A continuación, se presenta el codigo respectivo a la construcción del modelo de ***KNN***, teniendo en cuenta los ***hiperparametros*** especificados anteriormente. Además, se realiza la prueba de dicho modelo sobre el conjunto de datos, utilizando la función ***test_model2***. Con respecto a dicha función, se aplica como muestreo un ***cross-validation estratificado con k=10***.

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

bestknn = KNN(n_neighbors=15, weights='uniform', algorithm='brute')
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestknn, df, 10)

# %% [markdown]
# Avanzando en el tema, se procedera a reportar los valores obtenidos para una serie de ***metricas de evaluación***, dada la prueba realizada anteriormente. Dichas metricas seran utilizadas para la posterior comparación de modelos.

# %% [markdown]
# ####***A.1. Evaluación según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Exactitud (Accuracy)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Exactitud (Accuracy) obtenida con mejor modelo de KNN:", acc)
# Out:
# Exactitud (Accuracy) obtenida con mejor modelo de KNN: 0.9733333333333333

# %% [markdown]
# ####***A.2. Evaluación según metrica de Precisión (Precision)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Precisión (Precision)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de KNN:", prep)
print("Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de KNN:", pren)
# Out:
# Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de KNN: 0.9663968100965763
# Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de KNN: 0.9805697329364399

# %% [markdown]
# ####***A.3. Evaluación según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el ***Recall*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Recall para Fraude (clase positiva) obtenido con mejor modelo de KNN:", recp)
print("Recall para No fraude (clase negativa) obtenido con mejor modelo de KNN:", recn)
# Out:
# Recall para Fraude (clase positiva) obtenido con mejor modelo de KNN: 0.9808333333333336
# Recall para No fraude (clase negativa) obtenido con mejor modelo de KNN: 0.9658333333333333

# %% [markdown]
# ####***A.4. Evaluación según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el ***F1*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("F1 para Fraude (clase positiva) obtenido con mejor modelo de KNN:", f1p)
print("F1 para No fraude (clase negativa) obtenido con mejor modelo de KNN:", f1n)
# Out:
# F1 para Fraude (clase positiva) obtenido con mejor modelo de KNN: 0.9735397068456088
# F1 para No fraude (clase negativa) obtenido con mejor modelo de KNN: 0.9731224038985999

# %% [markdown]
# ####***A.5. Evaluación según metrica de Área bajo la Curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica el ***Área bajo la Curva ROC (AUC)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Área bajo la Curva ROC (AUC) obtenido con mejor modelo de KNN:", auc)
# Out:
# Área bajo la Curva ROC (AUC) obtenido con mejor modelo de KNN: 0.9948183834876543

# %% [markdown]
# ####***A.6. Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***KNN*** sobre el conjunto de datos en la prueba anterior. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Curvas ROC obtenidas con mejor modelo de KNN: ")
draw_rocs(bestknn, df, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo de KNN:

# %% [markdown]
# ###***B. Análisis del mejor modelo de Árbol de Decisión***

# %% [markdown]
# El ***mejor modelo*** encontrado para ***Árbol de Decisión*** se constituye de la siguiente configuración de ***hiperparametros***:
#
# * ***Maxima profundidad (max_depth): 16***
# * ***min_samples_split: 0.03***
# * ***min_samples_leaf: 0.01***
# * ***max_features: Logaritmo (log2)***

# %% [markdown]
# A continuación, se presenta el codigo respectivo a la construcción del modelo de ***Árbol de Decisión***, teniendo en cuenta los ***hiperparametros*** especificados anteriormente. Además, se realiza la prueba de dicho modelo sobre el conjunto de datos, utilizando la función ***test_model2***. Con respecto a dicha función, se aplica como muestreo un ***cross-validation estratificado con k=10***.

# %%
from sklearn.tree import DecisionTreeClassifier

bestdtc = DecisionTreeClassifier(max_depth=16, min_samples_split=0.03, min_samples_leaf=0.01, max_features='log2')
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestdtc, df, 10)

# %% [markdown]
# Avanzando en el tema, se procedera a reportar los valores obtenidos para una serie de ***metricas de evaluación***, dada la prueba realizada anteriormente. Dichas metricas seran utilizadas para la posterior comparación de modelos.

# %% [markdown]
# ####***B.1. Evaluación según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Exactitud (Accuracy)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Exactitud (Accuracy) obtenida con mejor modelo de Árbol de Decisión:", acc)
# Out:
# Exactitud (Accuracy) obtenida con mejor modelo de Árbol de Decisión: 0.9488888888888891

# %% [markdown]
# ####***B.2. Evaluación según metrica de Precisión (Precision)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Precisión (Precision)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Árbol de Decisión:", prep)
print("Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Árbol de Decisión:", pren)
# Out:
# Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Árbol de Decisión: 0.9233999127892879
# Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Árbol de Decisión: 0.9786455916004361

# %% [markdown]
# ####***B.3. Evaluación según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el ***Recall*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Recall para Fraude (clase positiva) obtenido con mejor modelo de Árbol de Decisión:", recp)
print("Recall para No fraude (clase negativa) obtenido con mejor modelo de Árbol de Decisión:", recn)
# Out:
# Recall para Fraude (clase positiva) obtenido con mejor modelo de Árbol de Decisión: 0.9795833333333333
# Recall para No fraude (clase negativa) obtenido con mejor modelo de Árbol de Decisión: 0.9181944444444443

# %% [markdown]
# ####***B.4. Evaluación según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el ***F1*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("F1 para Fraude (clase positiva) obtenido con mejor modelo de Árbol de Decisión:", f1p)
print("F1 para No fraude (clase negativa) obtenido con mejor modelo de Árbol de Decisión:", f1n)
# Out:
# F1 para Fraude (clase positiva) obtenido con mejor modelo de Árbol de Decisión: 0.9504552020239897
# F1 para No fraude (clase negativa) obtenido con mejor modelo de Árbol de Decisión: 0.9471909501853251

# %% [markdown]
# ####***B.5. Evaluación según metrica de Área bajo la Curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica el ***Área bajo la Curva ROC (AUC)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Árbol de Decisión:", auc)
# Out:
# Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Árbol de Decisión: 0.9879405864197531

# %% [markdown]
# ####***B.6. Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Árbol de Decisión*** sobre el conjunto de datos en la prueba anterior. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Curvas ROC obtenidas con mejor modelo de Árbol de Decisión: ")
draw_rocs(bestdtc, df, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo de Árbol de Decisión:

# %% [markdown]
# ###***C. Análisis del mejor modelo de Máquinas de Vectores de Soporte (SVM)***

# %% [markdown]
# El ***mejor modelo*** encontrado para ***Máquinas de Vectores de Soporte (SVM)*** se constituye de la siguiente configuración de ***hiperparametros***:
#
# * ***C (parametro de regularización): 135***
# * ***Kernel: Radial Basis Function (RBF)***

# %% [markdown]
# A continuación, se presenta el codigo respectivo a la construcción del modelo de ***Máquinas de Vectores de Soporte (SVM)***, teniendo en cuenta los ***hiperparametros*** especificados anteriormente. Además, se realiza la prueba de dicho modelo sobre el conjunto de datos, utilizando la función ***test_model2***. Con respecto a dicha función, se aplica como muestreo un ***cross-validation estratificado con k=10***.

# %%
from sklearn.svm import SVC

bestsvm = SVC(C=135, kernel='rbf', probability=True)
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestsvm, df, 10)

# %% [markdown]
# Avanzando en el tema, se procedera a reportar los valores obtenidos para una serie de ***metricas de evaluación***, dada la prueba realizada anteriormente. Dichas metricas seran utilizadas para la posterior comparación de modelos.

# %% [markdown]
# ####***C.1. Evaluación según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Exactitud (Accuracy)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Exactitud (Accuracy) obtenida con mejor modelo de Máquinas de Vectores de Soporte (SVM):", acc)
# Out:
# Exactitud (Accuracy) obtenida con mejor modelo de Máquinas de Vectores de Soporte (SVM): 0.9729166666666667

# %% [markdown]
# ####***C.2. Evaluación según metrica de Precisión (Precision)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Precisión (Precision)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Máquinas de Vectores de Soporte (SVM):", prep)
print("Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Máquinas de Vectores de Soporte (SVM):", pren)
# Out:
# Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Máquinas de Vectores de Soporte (SVM): 0.966597288841528
# Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Máquinas de Vectores de Soporte (SVM): 0.9794523793475239

# %% [markdown]
# ####***C.3. Evaluación según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el ***Recall*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Recall para Fraude (clase positiva) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM):", recp)
print("Recall para No fraude (clase negativa) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM):", recn)
# Out:
# Recall para Fraude (clase positiva) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM): 0.979722222222222
# Recall para No fraude (clase negativa) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM): 0.9661111111111111

# %% [markdown]
# ####***C.4. Evaluación según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el ***F1*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("F1 para Fraude (clase positiva) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM):", f1p)
print("F1 para No fraude (clase negativa) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM):", f1n)
# Out:
# F1 para Fraude (clase positiva) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM): 0.9731050754307453
# F1 para No fraude (clase negativa) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM): 0.9727250301349681

# %% [markdown]
# ####***C.5. Evaluación según metrica de Área bajo la Curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica el ***Área bajo la Curva ROC (AUC)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM):", auc)
# Out:
# Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Máquinas de Vectores de Soporte (SVM): 0.9922869405864198

# %% [markdown]
# ####***C.6. Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Máquinas de Vectores de Soporte (SVM)*** sobre el conjunto de datos en la prueba anterior. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Curvas ROC obtenidas con mejor modelo de Máquinas de Vectores de Soporte (SVM): ")
draw_rocs(bestsvm, df, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo de Máquinas de Vectores de Soporte (SVM):

# %% [markdown]
# ###***D. Análisis del mejor modelo de Random Forest***

# %% [markdown]
# El ***mejor modelo*** encontrado para ***Random Forest*** se constituye de la siguiente configuración de ***hiperparametros***:
#
# * ***Numero de estimadores (n_estimators):  200***
# * ***Profundidad maxima (max_depth):  10***
# * ***max_features:  auto***
# * ***bootstrap:  True***

# %% [markdown]
# A continuación, se presenta el codigo respectivo a la construcción del modelo de ***Random Forest***, teniendo en cuenta los ***hiperparametros*** especificados anteriormente. Además, se realiza la prueba de dicho modelo sobre el conjunto de datos, utilizando la función ***test_model2***. Con respecto a dicha función, se aplica como muestreo un ***cross-validation estratificado con k=10***.

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

bestrfc = RFC(n_estimators=200, max_depth=10, max_features='auto', bootstrap=True)
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestrfc, df, 10)

# %% [markdown]
# Avanzando en el tema, se procedera a reportar los valores obtenidos para una serie de ***metricas de evaluación***, dada la prueba realizada anteriormente. Dichas metricas seran utilizadas para la posterior comparación de modelos.

# %% [markdown]
# ####***D.1. Evaluación según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Exactitud (Accuracy)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Exactitud (Accuracy) obtenida con mejor modelo de Random Forest:", acc)
# Out:
# Exactitud (Accuracy) obtenida con mejor modelo de Random Forest: 0.9728472222222223

# %% [markdown]
# ####***D.2. Evaluación según metrica de Precisión (Precision)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Precisión (Precision)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Random Forest:", prep)
print("Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Random Forest:", pren)
# Out:
# Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Random Forest: 0.9667543878017018
# Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Random Forest: 0.979223113786784

# %% [markdown]
# ####***D.3. Evaluación según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el ***Recall*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Recall para Fraude (clase positiva) obtenido con mejor modelo de Random Forest:", recp)
print("Recall para No fraude (clase negativa) obtenido con mejor modelo de Random Forest:", recn)
# Out:
# Recall para Fraude (clase positiva) obtenido con mejor modelo de Random Forest: 0.9794444444444445
# Recall para No fraude (clase negativa) obtenido con mejor modelo de Random Forest: 0.9662499999999999

# %% [markdown]
# ####***D.4. Evaluación según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el ***F1*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("F1 para Fraude (clase positiva) obtenido con mejor modelo de Random Forest:", f1p)
print("F1 para No fraude (clase negativa) obtenido con mejor modelo de Random Forest:", f1n)
# Out:
# F1 para Fraude (clase positiva) obtenido con mejor modelo de Random Forest: 0.9730281768709206
# F1 para No fraude (clase negativa) obtenido con mejor modelo de Random Forest: 0.9726621001577588

# %% [markdown]
# ####***D.5. Evaluación según metrica de Área bajo la Curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica el ***Área bajo la Curva ROC (AUC)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Random Forest:", auc)
# Out:
# Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Random Forest: 0.9960536265432098

# %% [markdown]
# ####***D.6. Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Random Forest*** sobre el conjunto de datos en la prueba anterior. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Curvas ROC obtenidas con mejor modelo de Random Forest: ")
draw_rocs(bestrfc, df, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo de Random Forest:

# %% [markdown]
# ###***E. Análisis del mejor modelo de Regresión Logistica (Logistic Regression)***

# %% [markdown]
# El ***mejor modelo*** encontrado para ***Regresión Logistica (Logistic Regression)*** se constituye de la siguiente configuración de ***hiperparametros***:
#
# * ***C (parametro de regularización):  245***
# * ***class_weight:  Balanceado (balanced)***
# * ***Solucionador (solver):  liblinear***

# %% [markdown]
# A continuación, se presenta el codigo respectivo a la construcción del modelo de ***Regresión Logistica (Logistic Regression)***, teniendo en cuenta los ***hiperparametros*** especificados anteriormente. Además, se realiza la prueba de dicho modelo sobre el conjunto de datos, utilizando la función ***test_model2***. Con respecto a dicha función, se aplica como muestreo un ***cross-validation estratificado con k=10***.

# %%
from sklearn.linear_model import LogisticRegression as LR

bestlr = LR(C=245, class_weight='balanced', solver='liblinear')
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestlr, df, 10)

# %% [markdown]
# Avanzando en el tema, se procedera a reportar los valores obtenidos para una serie de ***metricas de evaluación***, dada la prueba realizada anteriormente. Dichas metricas seran utilizadas para la posterior comparación de modelos.

# %% [markdown]
# ####***E.1. Evaluación según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Exactitud (Accuracy)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Exactitud (Accuracy) obtenida con mejor modelo de Regresión Logistica (Logistic Regression):", acc)
# Out:
# Exactitud (Accuracy) obtenida con mejor modelo de Regresión Logistica (Logistic Regression): 0.9090972222222223

# %% [markdown]
# ####***E.2. Evaluación según metrica de Precisión (Precision)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Precisión (Precision)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Regresión Logistica (Logistic Regression):", prep)
print("Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Regresión Logistica (Logistic Regression):", pren)
# Out:
# Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Regresión Logistica (Logistic Regression): 0.9555743683641758
# Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Regresión Logistica (Logistic Regression): 0.8714876768710121

# %% [markdown]
# ####***E.3. Evaluación según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el ***Recall*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Recall para Fraude (clase positiva) obtenido con mejor modelo de Regresión Logistica (Logistic Regression):", recp)
print("Recall para No fraude (clase negativa) obtenido con mejor modelo de Regresión Logistica (Logistic Regression):", recn)
# Out:
# Recall para Fraude (clase positiva) obtenido con mejor modelo de Regresión Logistica (Logistic Regression): 0.8581944444444444
# Recall para No fraude (clase negativa) obtenido con mejor modelo de Regresión Logistica (Logistic Regression): 0.96

# %% [markdown]
# ####***E.4. Evaluación según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el ***F1*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("F1 para Fraude (clase positiva) obtenido con mejor modelo de Regresión Logistica (Logistic Regression):", f1p)
print("F1 para No fraude (clase negativa) obtenido con mejor modelo de Regresión Logistica (Logistic Regression):", f1n)
# Out:
# F1 para Fraude (clase positiva) obtenido con mejor modelo de Regresión Logistica (Logistic Regression): 0.9041600943774158
# F1 para No fraude (clase negativa) obtenido con mejor modelo de Regresión Logistica (Logistic Regression): 0.913533352879132

# %% [markdown]
# ####***E.5. Evaluación según metrica de Área bajo la Curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica el ***Área bajo la Curva ROC (AUC)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Regresión Logistica (Logistic Regression):", auc)
# Out:
# Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Regresión Logistica (Logistic Regression): 0.9567196180555555

# %% [markdown]
# ####***E.6. Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Regresión Logistica (Logistic Regression)*** sobre el conjunto de datos en la prueba anterior. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Curvas ROC obtenidas con mejor modelo de Regresión Logistica (Logistic Regression): ")
draw_rocs(bestlr, df, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo de Regresión Logistica (Logistic Regression):

# %% [markdown]
# ###***F. Análisis del mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes)***

# %% [markdown]
# El ***mejor modelo*** encontrado para ***Redes Bayesianas Multinomiales (Multinomial Naive Bayes)*** se constituye de la siguiente configuración de ***hiperparametros***:
#
# * ***alpha:  0***
# * ***fit_prior:  True***

# %% [markdown]
# A continuación, se presenta el codigo respectivo a la construcción del modelo de ***Redes Bayesianas Multinomiales (Multinomial Naive Bayes)***, teniendo en cuenta los ***hiperparametros*** especificados anteriormente. Además, se realiza la prueba de dicho modelo sobre el conjunto de datos, utilizando la función ***test_model2***. Con respecto a dicha función, se aplica como muestreo un ***cross-validation estratificado con k=10***.

# %%
from sklearn.naive_bayes import MultinomialNB

bestmnb = MultinomialNB(alpha=0, fit_prior=True)
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestmnb, dfn, 10)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# ...

# %% [markdown]
# Avanzando en el tema, se procedera a reportar los valores obtenidos para una serie de ***metricas de evaluación***, dada la prueba realizada anteriormente. Dichas metricas seran utilizadas para la posterior comparación de modelos.

# %% [markdown]
# ####***F.1. Evaluación según metrica de Exactitud (Accuracy)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Exactitud (Accuracy)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Exactitud (Accuracy) obtenida con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):", acc)
# Out:
# Exactitud (Accuracy) obtenida con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): 0.8240972222222223

# %% [markdown]
# ####***F.2. Evaluación según metrica de Precisión (Precision)***

# %% [markdown]
# En el siguiente codigo, se indica la ***Precisión (Precision)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):", prep)
print("Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):", pren)
# Out:
# Precisión (Precision) para Fraude (clase positiva) obtenida con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): 0.8352705484201394
# Precisión (Precision) para No fraude (clase negativa) obtenida con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): 0.8144828742010037

# %% [markdown]
# ####***F.3. Evaluación según metrica de Recall***

# %% [markdown]
# En el siguiente codigo, se indica el ***Recall*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Recall para Fraude (clase positiva) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):", recp)
print("Recall para No fraude (clase negativa) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):", recn)
# Out:
# Recall para Fraude (clase positiva) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): 0.8081944444444444
# Recall para No fraude (clase negativa) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): 0.8400000000000001

# %% [markdown]
# ####***F.4. Evaluación según metrica de F1***

# %% [markdown]
# En el siguiente codigo, se indica el ***F1*** obtenido con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("F1 para Fraude (clase positiva) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):", f1p)
print("F1 para No fraude (clase negativa) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):", f1n)
# Out:
# F1 para Fraude (clase positiva) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): 0.8211996967317038
# F1 para No fraude (clase negativa) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): 0.8267825413540075

# %% [markdown]
# ####***F.5. Evaluación según metrica de Área bajo la Curva ROC (AUC)***

# %% [markdown]
# En el siguiente codigo, se indica el ***Área bajo la Curva ROC (AUC)*** obtenida con la prueba anterior. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):", auc)
# Out:
# Área bajo la Curva ROC (AUC) obtenido con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): 0.8611524884259258

# %% [markdown]
# ####***F.6. Evaluación según gráfico de Curvas Receiver Operating Characteristics (ROC)***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Redes Bayesianas Multinomiales (Multinomial Naive Bayes)*** sobre el conjunto de datos en la prueba anterior. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***. Cabe mencionar que se tuvieron en cuenta los mejores ***hiperparametros*** para el modelo.

# %%
print("Curvas ROC obtenidas con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes): ")
draw_rocs(bestmnb, dfn, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo de Redes Bayesianas Multinomiales (Multinomial Naive Bayes):
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# ...

# %% [markdown]
# ###***G. Comparación y Conclusiones***

# %% [markdown]
# En esta sección, se procede con la construcción de la síntesis o resumen de los resultados obtenidos para cada modelo. Se empleara una comparación entre los mismos, con el objetivo de plantear conclusiones apropiadas. La comparativa se desarrolla en base a una serie de metricas. Entre ellas, cabe mencionar ***Exactitud, Precisión, Recall, F1*** y ***Área bajo la curva ROC (AUC)***. Siguiendo en este razonamiento, se procede a mostrar una tabla, la cual indica los valores de las ***metricas de evaluación*** obtenidos por el ***mejor modelo*** de cada algoritmo de aprendizaje supervisado analizado. Esta tabla es formulada con el objetivo de resaltar las limitaciones y ventajas de cada modelo de forma comparativa. Es importante resaltar que un ***mejor modelo*** de un clasificador, es aquel que cuenta con los mejores ***hiperparametros*** encontrados para el mismo.
#
# ![Tabla comparativa de modelos](https://i.ibb.co/wBpD1vS/tabcomp6clasfs.png)

# %% [markdown]
# De acuerdo a lo observado en la tabla anterior, es factible reconocer que el ***mejor modelo*** de ***KNN*** logra obtener mejor ***performance*** que el resto de modelos en base a ***2 metricas***, las cuales son ***Exactitud y F1***. Por otra parte, se logra observar que el ***mejor modelo*** de ***Random Forest*** alcanza un mejor valor de ***AUC*** que el resto de modelos evaluados. Teniendo ello en cuenta, se procedera a listar cada ***metrica de evaluación***, realizando la comparativa entre modelos respectiva:
#
# * ***KNN (mejor modelo)*** logra obtener una mejor ***Exactitud***, con un valor de ***97.33%***, en comparación a los ***94.89%***, ***97.29%***, ***97.28%***, ***90.91%*** y ***82.41%*** obtenidos por ***Árbol de Decisión (mejor modelo)***, ***SVM (mejor modelo)***, ***Random Forest (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)*** respectivamente.
#
# * ***Random Forest (mejor modelo)*** logra obtener una mejor ***Precisión para Fraude***, con un valor de ***96.68%***, en comparación a los ***96.64%***, ***92.34%***, ***96.66%***, ***95.56%*** y ***83.53%*** obtenidos por ***KNN (mejor modelo)***, ***Árbol de Decisión (mejor modelo)***, ***SVM (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)*** respectivamente.
#
# * ***KNN (mejor modelo)*** logra obtener una mejor ***Precisión para No Fraude***, con un valor de ***98.06%***, en comparación a los ***97.86%***, ***97.95%***, ***97.92%***, ***87.15%*** y ***81.45%*** obtenidos por ***Árbol de Decisión (mejor modelo)***, ***SVM (mejor modelo)***, ***Random Forest (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)*** respectivamente.
#
# * ***KNN (mejor modelo)*** logra obtener un mejor ***Recall para Fraude***, con un valor de ***98.08%***, en comparación a los ***97.96%***, ***97.97%***, ***97.94%***, ***85.82%*** y ***80.82%*** obtenidos por ***Árbol de Decisión (mejor modelo)***, ***SVM (mejor modelo)***, ***Random Forest (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)*** respectivamente.
#
# * ***Random Forest (mejor modelo)*** logra obtener un mejor ***Recall para No Fraude***, con un valor de ***96.62%***, en comparación a los ***96.58%***, ***91.82%***, ***96.61%***, ***96.00%*** y ***84.00%*** obtenidos por ***KNN (mejor modelo)***, ***Árbol de Decisión (mejor modelo)***, ***SVM (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)*** respectivamente.
#
# * ***KNN (mejor modelo)*** logra obtener un mejor ***F1 para Fraude***, con un valor de ***97.35%***, en comparación a los ***95.05%***, ***97.31%***, ***97.30%***, ***90.42%*** y ***82.12%*** obtenidos por ***Árbol de Decisión (mejor modelo)***, ***SVM (mejor modelo)***, ***Random Forest (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)*** respectivamente.
#
# * ***KNN (mejor modelo)*** logra obtener un mejor ***F1 para No Fraude***, con un valor de ***97.31%***, en comparación a los ***94.72%***, ***97.27%***, ***97.27%***, ***91.35%*** y ***82.68%*** obtenidos por ***Árbol de Decisión (mejor modelo)***, ***SVM (mejor modelo)***, ***Random Forest (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)*** respectivamente.
#
# * ***Random Forest (mejor modelo)*** logra obtener una mejor ***Área bajo la curva ROC***, con un valor de ***99.61%***, en comparación a los ***99.48%***, ***98.79%***, ***99.23%***, ***95.67%*** y ***86.12%*** obtenidos por ***KNN (mejor modelo)***, ***Árbol de Decisión (mejor modelo)***, ***SVM (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)*** respectivamente.

# %% [markdown]
# Como se puede observar, para la mayoria de metricas, ***KNN (mejor modelo)*** logra obtener los mejores resultados. Sin embargo, la diferencia en cuanto a desempeño entre ***KNN (mejor modelo)***, ***SVM (mejor modelo)*** y ***Random Forest (mejor modelo)*** es inferior a ***0.2%*** para todas las metricas analizadas exepto ***Área bajo la curva ROC (AUC)***. Para ***AUC***, la diferencia de desempeño entre los clasificadores mencionados es inferior a ***0.4%***. Por ende, se argumenta que la diferencia de desempeño entre ***KNN (mejor modelo)***, ***SVM (mejor modelo)*** y ***Random Forest (mejor modelo)*** es poco significativa como para afirmar contundentemente la superioridad de uno de estos.
#
# Por otro lado, tambien es importante argumentar respecto a ***1 metrica*** en especifico para identificar el mejor clasificador. En ese sentido, dicha metrica sera ***F1***. ***KNN (mejor modelo)*** consigue ser el más apropiado para optimizar el valor de ***F1 para Fraude*** y ***F1 para No Fraude***. Por consiguiente, se concluye que se obtiene el mejor ***F1*** con el ***mejor modelo*** de ***KNN***, obteniendo un valor de ***97.35%*** en ***F1 para Fraude*** y ***97.31%*** en ***F1 para No Fraude***. No obstante, los valores de ***F1*** obtenidos por ***SVM (mejor modelo)*** y ***Random Forest (mejor modelo)*** presentan una diferencia inferior a ***0.1%*** respecto a lo obtenido por ***KNN***. Por lo tanto, respecto a ***F1***, tampoco se puede afirmar contundentemente la superioridad de alguno de los ***3*** algoritmos mencionados. Además, de acuerdo a los resultados obtenidos, cabe mencionar que ***KNN***, ***SVM*** y ***Random Forest*** si logran ser significativamente superiores a los otros ***3*** algoritmos de aprendizaje supervisado evaluados, los cuales son ***Árbol de Decisión (mejor modelo)***, ***Logistic Regression (mejor modelo)*** y ***Multinomial Naive Bayes (mejor modelo)***. En ese sentido, se reporta lo siguiente:
#
# * ***Los mejor modelos encontrados para el conjunto de datos estan basados en K Vecinos más Cercanos (KNN), Maquinas de Vectores de Soporte (SVM) y Random Forest***.
#
# Asimismo, los siguientes ajustes de ***hiperparametros*** son los más apropiados para los modelos planteados:
#
# * ***Para K Vecinos más Cercanos (KNN):***
#   * ***Numero de vecinos (n_neighbors): 15***
#   * ***Pesos (weights): Uniform***
#   * ***Algoritmo (algorithm): Brute***
#
# * ***Para Maquinas de Vectores de Soporte (SVM):***
#   * ***C (parametro de regularización): 135***
#   * ***Kernel: Radial Basis Function (RBF)***
#
# * ***Para Random Forest:***
#   * ***Numero de estimadores (n_estimators):  200***
#   * ***Profundidad maxima (max_depth):  10***
#   * ***max_features:  auto***
#   * ***bootstrap:  True***
#
# ***Conclusión: No se puede afirmar la superioridad de uno de los 3 algortimos de aprendizaje supervisado reportados anteriormente, por lo que se afirma que los 3 son los que funcionan mejor con el conjunto de datos***

# %% [markdown]
# ####***G.1. Gráfico de Curvas Receiver Operating Characteristics (ROC) para K Vecinos más Cercanos (KNN)***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***KNN*** sobre el conjunto de datos. Cabe mencionar que se tienen en cuenta los mejores hiperparametros para el modelo. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

bestknn = KNN(n_neighbors=15, weights='uniform', algorithm='brute')
print("Curvas ROC obtenidas con mejor modelo para el conjunto de datos: ")
draw_rocs(bestknn, df, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo para el conjunto de datos:

# %% [markdown]
# ####***G.2. Gráfico de Curvas Receiver Operating Characteristics (ROC) para Maquinas de Vectores de Soporte (SVM)***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***SVM*** sobre el conjunto de datos. Cabe mencionar que se tienen en cuenta los mejores hiperparametros para el modelo. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
from sklearn.svm import SVC

bestsvm = SVC(C=135, kernel='rbf', probability=True)
print("Curvas ROC obtenidas con mejor modelo para el conjunto de datos: ")
draw_rocs(bestsvm, df, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo para el conjunto de datos:

# %% [markdown]
# ####***G.3. Gráfico de Curvas Receiver Operating Characteristics (ROC) para Random Forest***

# %% [markdown]
# Se procedera a graficar la curva ***ROC*** asociada a la aplicación del modelo ***Random Forest*** sobre el conjunto de datos. Cabe mencionar que se tienen en cuenta los mejores hiperparametros para el modelo. Asimismo, se utiliza un muestreo de ***cross-validation estratificado con k=10***. En ese sentido, en el grafico, tambien se indica el ***AUC*** de cada ***Fold*** evaluado en el ***cross-validation***.

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

bestrfc = RFC(n_estimators=200, max_depth=10, max_features='auto', bootstrap=True)
print("Curvas ROC obtenidas con mejor modelo para el conjunto de datos: ")
draw_rocs(bestrfc, df, 10)
# Out:
# Curvas ROC obtenidas con mejor modelo para el conjunto de datos:

# %% [markdown]
# ###***F. Identificación de Overfitting en los mejores modelos encontrados***

# %% [markdown]
# A continuación, se procedera a identificar si los ***3*** mejores algoritmos de aprendizaje supervisado determinados, los cuales fueron concluidos como los mejores modelos para el conjunto de datos en la sección anterior, presentan problemas relacionados a ***Overfitting***. Dicho algoritmos son ***K Vecinos más Cercanos (KNN)***, ***Maquinas de Vectores de Soporte (SVM)*** y ***Random Forest***.

# %% [markdown]
# ####***F.1. Identificación de Overfitting para K Vecinos más Cercanos (KNN)***

# %% [markdown]
# Para la identificación de ***Overfitting***, se plantea ampliar el numero de Folds en el ***cross-validation estratificado***. En este caso, sera un valor de ***K*** igual a ***50***. En el siguiente codigo, se realiza la prueba respectiva de ***KNN*** y se logra comprobar que el desempeño del clasificador se mantiene a pesar de haber aumentado el numero de conjuntos de prueba. En ese sentido, se reduce la posibilidad de posible ***Overfitting***.

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

bestknn = KNN(n_neighbors=15, weights='uniform', algorithm='brute')
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestknn, df, 50)
print("Exactitud (Accuracy):", acc)
print("Presición para Fraude:", prep)
print("Recall para Fraude:", recp)
print("F1 para Fraude:", f1p)
print("Presición para No Fraude:", pren)
print("Recall para No Fraude:", recn)
print("F1 para No Fraude:", f1n)
print("Área bajo la curva ROC (AUC):", auc)
# Out:
# Exactitud (Accuracy): 0.9736111111111109
# Presición para Fraude: 0.9670698007725791
# Recall para Fraude: 0.9808333333333337
# F1 para Fraude: 0.9738165382947669
# Presición para No Fraude: 0.9806967207673807
# Recall para No Fraude: 0.9663888888888893
# F1 para No Fraude: 0.9733967834494445
# Área bajo la curva ROC (AUC): 0.9947154706790121

# %% [markdown]
# ####***F.2. Identificación de Overfitting para Maquinas de Vectores de Soporte (SVM)***

# %% [markdown]
# Para la identificación de ***Overfitting***, se plantea ampliar el numero de Folds en el ***cross-validation estratificado***. En este caso, sera un valor de ***K*** igual a ***50***. En el siguiente codigo, se realiza la prueba respectiva de ***SVM*** y se logra comprobar que el desempeño del clasificador se mantiene a pesar de haber aumentado el numero de conjuntos de prueba. En ese sentido, se reduce la posibilidad de posible ***Overfitting***.

# %%
from sklearn.svm import SVC

bestsvm = SVC(C=135, kernel='rbf', probability=True)
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestsvm, df, 50)
print("Exactitud (Accuracy):", acc)
print("Presición para Fraude:", prep)
print("Recall para Fraude:", recp)
print("F1 para Fraude:", f1p)
print("Presición para No Fraude:", pren)
print("Recall para No Fraude:", recn)
print("F1 para No Fraude:", f1n)
print("Área bajo la curva ROC (AUC):", auc)
# Out:
# Exactitud (Accuracy): 0.9727777777777779
# Presición para Fraude: 0.9663473834157744
# Recall para Fraude: 0.9798611111111113
# F1 para Fraude: 0.9729904710745185
# Presición para No Fraude: 0.979665704933914
# Recall para No Fraude: 0.9656944444444445
# F1 para No Fraude: 0.9725572438157724
# Área bajo la curva ROC (AUC): 0.9917563657407408

# %% [markdown]
# ####***F.3. Identificación de Overfitting para Random Forest***

# %% [markdown]
# Para la identificación de ***Overfitting***, se plantea ampliar el numero de Folds en el ***cross-validation estratificado***. En este caso, sera un valor de ***K*** igual a ***50***. En el siguiente codigo, se realiza la prueba respectiva de ***Random Forest*** y se logra comprobar que el desempeño del clasificador se mantiene a pesar de haber aumentado el numero de conjuntos de prueba. En ese sentido, se reduce la posibilidad de posible ***Overfitting***.

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

bestrfc = RFC(n_estimators=200, max_depth=10, max_features='auto', bootstrap=True)
acc, prep, recp, f1p, pren, recn, f1n, auc = test_model2(bestrfc, df, 50)
print("Exactitud (Accuracy):", acc)
print("Presición para Fraude:", prep)
print("Recall para Fraude:", recp)
print("F1 para Fraude:", f1p)
print("Presición para No Fraude:", pren)
print("Recall para No Fraude:", recn)
print("F1 para No Fraude:", f1n)
print("Área bajo la curva ROC (AUC):", auc)
# Out:
# Exactitud (Accuracy): 0.973333333333333
# Presición para Fraude: 0.9677715040760997
# Recall para Fraude: 0.9794444444444445
# F1 para Fraude: 0.9734968751755655
# Presición para No Fraude: 0.979339469893755
# Recall para No Fraude: 0.9672222222222223
# F1 para No Fraude: 0.9731630544316697
# Área bajo la curva ROC (AUC): 0.9960339506172841

# %% [markdown]
# ##***3. Aplicación de aprendizaje no supervisado***

# %% [markdown]
# En esta parte, se plantea el uso de ***aprendizaje no supervisado*** para caracterizar el conjunto de datos. Se buscarán patrones evidentes en dicho conjunto, con el objetivo de determinar algún tipo de tratamiento de datos a aplicar. El objetivo de este tratamiento es mejorar el desempeño de clasificación de los algoritmos de aprendizaje supervisado sobre el conjunto de datos analizado.

# %% [markdown]
# ###***A. Aplicación de K-means***

# %% [markdown]
# A continuación, se presenta el conjunto de datos sobre el que se aplicará ***K-means***. Cabe mencionar que no se utilizara la columna ***fraude***, puesto que esta indica la clase. La idea de los algoritmos de ***aprendizaje no supervisado*** es que puedan clasificar los datos sin nunguna referencia previa.

# %%
df.head()
# Out:
#    merchant  category    amount  fraud
# 0  0.112970 -2.059185 -0.258553      0
# 1 -0.961731  0.711071 -0.424551      0
# 2 -0.961731  0.711071 -0.418219      0
# 3 -0.961731  0.711071 -0.417034      0
# 4  1.270340 -1.782160 -0.346511      0

# %% [markdown]
# En el siguiente codigo, se aplica la tecnica de ***K-means*** sobre el conjunto de datos. Los datos son separados en caracteristicas y columna objetivo respectivamente. Con ***K-means*** se pueden generar grupos o clusters en los datos, es decir, se pueden separar los datos dado un numero de clusters a generar. En este caso, se indica la generación de 2 clusters.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

X = df.iloc[:,:-1].values #Caracteristicas
Y = df.iloc[:,-1].values #Columna objetivo

km = KMeans(n_clusters=2) #Aplicación de K-means
km.fit(X)
y_km = km.predict(X)

# %% [markdown]
# ####***A.1. Visualización de K-means: Comerciante (merchant) vs Categoría (category)***

# %% [markdown]
# El siguiente código permite visualizar la aplicación de ***K-means*** sobre el conjunto de datos. En el siguiente cuadro, se muestra el grafico de dispersión entre los atributos ***Comerciante (merchant)*** y ***Categoría (category)***. Asimismo, en dicho gráfico, los colores indican el cluster o grupo asignado a cada instancia, dada la aplicación de ***K-means***. En este caso, se han generado ***2*** grupos.

# %%
plt.scatter(X[:,0], X[:,1], c=y_km, s=50, cmap='viridis')
plt.xlabel("Comerciante (merchant)")
plt.ylabel("Categoria (category)")
plt.show()

# %% [markdown]
# Ahora bien, respecto al siguiente cuadro, se muestra el mismo grafico de dispersión. No obstante, esta vez los colores indican la clase respectiva de cada instancia, es decir, si se trata de ***fraude*** o ***no fraude***.

# %%
plt.scatter(X[:,0], X[:,1], c=Y, s=50, cmap='viridis')
plt.xlabel("Comerciante (merchant)")
plt.ylabel("Categoria (category)")
plt.show()

# %% [markdown]
# Como se puede observar, bajo la perspectiva de esta visualización, la agrupación dada por la técnica de clusterización (***K-means***) difiere bastante de la clasificación de los datos respecto a si se trata de ***fraude*** o no. En ese sentido, respecto a la visualización suscitada, no se logran identificar patrones o relaciones evidentes que puedan representar una mejora en el desempeño de los clasificadores, a partir de un tratamiento sobre los datos.

# %% [markdown]
# ####***A.2. Visualización de K-means: Comerciante (merchant) vs Cantidad (amount)***

# %% [markdown]
# El siguiente código permite visualizar la aplicación de ***K-means*** sobre el conjunto de datos. En el siguiente cuadro, se muestra el grafico de dispersión entre los atributos ***Comerciante (merchant)*** y ***Cantidad (amount)***. Asimismo, en dicho gráfico, los colores indican el cluster o grupo asignado a cada instancia, dada la aplicación de ***K-means***. En este caso, se han generado ***2*** grupos.

# %%
plt.scatter(X[:,0], X[:,2], c=y_km, s=50, cmap='viridis')
plt.xlabel("Comerciante (merchant)")
plt.ylabel("Cantidad (amount)")
plt.show()

# %% [markdown]
# Ahora bien, respecto al siguiente cuadro, se muestra el mismo grafico de dispersión. No obstante, esta vez los colores indican la clase respectiva de cada instancia, es decir, si se trata de ***fraude*** o ***no fraude***.

# %%
plt.scatter(X[:,0], X[:,2], c=Y, s=50, cmap='viridis')
plt.xlabel("Comerciante (merchant)")
plt.ylabel("Cantidad (amount)")
plt.show()

# %% [markdown]
# Como se puede observar, bajo la perspectiva de esta visualización, la agrupación dada por la técnica de clusterización (***K-means***) difiere de la clasificación de los datos respecto a si se trata de ***fraude*** o no. En ese sentido, respecto a la visualización suscitada, no se logran identificar patrones o relaciones evidentes que puedan representar una mejora en el desempeño de los clasificadores, a partir de un tratamiento sobre los datos.

# %% [markdown]
# ####***A.3. Visualización de K-means: Categoría (category) vs Cantidad (amount)***

# %% [markdown]
# El siguiente código permite visualizar la aplicación de ***K-means*** sobre el conjunto de datos. En el siguiente cuadro, se muestra el grafico de dispersión entre los atributos ***Categoría (category)*** y ***Cantidad (amount)***. Asimismo, en dicho gráfico, los colores indican el cluster o grupo asignado a cada instancia, dada la aplicación de ***K-means***. En este caso, se han generado ***2*** grupos.

# %%
plt.scatter(X[:,1], X[:,2], c=y_km, s=50, cmap='viridis')
plt.xlabel("Categoría (category)")
plt.ylabel("Cantidad (amount)")
plt.show()

# %% [markdown]
# Ahora bien, respecto al siguiente cuadro, se muestra el mismo grafico de dispersión. No obstante, esta vez los colores indican la clase respectiva de cada instancia, es decir, si se trata de ***fraude*** o ***no fraude***.

# %%
plt.scatter(X[:,1], X[:,2], c=Y, s=50, cmap='viridis')
plt.xlabel("Categoría (category)")
plt.ylabel("Cantidad (amount)")
plt.show()

# %% [markdown]
# Como se puede observar, bajo la perspectiva de esta visualización, la agrupación dada por la técnica de clusterización (***K-means***) difiere de la clasificación de los datos respecto a si se trata de ***fraude*** o no. En ese sentido, respecto a la visualización suscitada, no se logran identificar patrones o relaciones evidentes que puedan representar una mejora en el desempeño de los clasificadores, a partir de un tratamiento sobre los datos.

# %% [markdown]
# ####***A.4. Visualización de K-means: Comerciante (merchant) vs Categoría (category) vs Cantidad (amount)***

# %% [markdown]
# El siguiente código permite visualizar la aplicación de ***K-means*** sobre el conjunto de datos. En el siguiente cuadro, se muestra el grafico de dispersión en ***3*** dimensiones entre los atributos ***Comerciante (merchant)***, ***Categoría (category)*** y ***Cantidad (amount)***. Asimismo, en dicho gráfico, los colores indican el cluster o grupo asignado a cada instancia, dada la aplicación de ***K-means***. En este caso, se han generado ***2*** grupos.

# %%
ax = plt.axes(projection = '3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c=y_km)

# %% [markdown]
# Ahora bien, respecto al siguiente cuadro, se muestra el mismo grafico de dispersión en ***3*** dimesniones. No obstante, esta vez los colores indican la clase respectiva de cada instancia, es decir, si se trata de ***fraude*** o ***no fraude***.

# %%
ax = plt.axes(projection = '3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c=Y)

# %% [markdown]
# Como se puede observar, bajo la perspectiva de esta visualización, la agrupación dada por la técnica de clusterización (***K-means***) difiere bastante de la clasificación de los datos respecto a si se trata de ***fraude*** o no. En ese sentido, respecto a la visualización suscitada, no se logran identificar patrones o relaciones evidentes que puedan representar una mejora en el desempeño de los clasificadores, a partir de un tratamiento sobre los datos.

# %% [markdown]
# ####***A.5. Identificación de patrones y Conclusiones***

# %% [markdown]
# En esta sección, se procede con la construcción de la síntesis o resumen de los resultados obtenidos dada la aplicación de ***aprendizaje no supervisado***. Se empleará un analisís de los mismos, con el objetivo de plantear conclusiones apropiadas. Se aplico el algoritmo de ***aprendizaje no supervisado*** correspondiente a ***K-means*** o ***K-medias*** sobre el conjunto de datos dado. Se obtuvieron ***2*** grupos o clusters en los datos, a partir de la aplicación de la tecnica mencionada. Luego de ello, se procedio con la visualización de los datos desde ***4*** perspectivas diferentes. En cada tipo de visualización, se realizó una comparación entre la agrupación dada por ***K-means*** y la clasificación de los datos. La cantidad de clusters era equivalente al número de clases en el conjunto de datos, por lo que se hizo prudente la comparación de ambas agrupaciones. Con respecto al gráfico de dispersión entre los atributos ***Comerciante (merchant)*** y ***Categoría (category)***, se hizo muestra de la ***clusterización*** dada por ***K-means***, a partir de colores. Asimismo, respecto a dicho gráfico de dispersión, en una segunda figura, se hizo muestra de la ***clasificación*** de los datos (***fraude*** o no ***fraude***), a partir de colores. Lo mismo se realizó para los graficos de dispersión ***Comerciante (merchant) vs Cantidad (amount)***, ***Categoría (category) vs Cantidad (amount)***, ***Comerciante (merchant) vs Categoría (category) vs Cantidad (amount)***. De esta manera, fue factible realizar una comparativa, de forma visual, entre los grupos generados por ***aprendizaje no supervisado*** y los grupos dados por la clasificación de los datos respecto a si es ***fraude*** o no. Como resultado de la comparación en cada una de las perspectivas visuales empleadas, se logró identificar que la ***clusterización*** dada por la técnica de ***K-means*** no presenta suficiente relación con la ***clasificación*** de los datos. Por lo tanto, respecto a los aspectos abordados, no se encuentran patrones evidentes que puedan significar una mejora en el desempeño de los algoritmos de ***aprendizaje supervisado***, a partir de un tratamiento sobre los datos.
#
# ***Conclusión: No se encuentran patrones evidentes que pueden servir para el tratamiento de los datos y su uso con aprendizaje supervisado.***
